# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#! pip install xgboost
# Models (Regressors)
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.dummy import DummyRegressor
from xgboost import XGBRegressor 

# Model tools
from lightgbm import plot_importance
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.model_selection import StratifiedKFold, cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.tree import plot_tree

# Measurements 
from sklearn.metrics import r2_score, explained_variance_score, mean_absolute_error, mean_squared_error
from sklearn.metrics import confusion_matrix, classification_report, log_loss
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.linear_model import LassoCV, Lasso
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression, Ridge

# Engineering
from sklearn.preprocessing import LabelEncoder
from imblearn.over_sampling import RandomOverSampler

# Other
from tqdm.notebook import tqdm
from time import sleep
from datetime import datetime

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.options.mode.chained_assignment = None  # default='warn'
sns.set_palette('deep', n_colors=7)
sns.set_style("whitegrid", {"axes.facecolor": ".9"})

# %%
#import data
df_train = pd.read_csv('Data_Train.csv') 
df_test = pd.read_csv('Test_set.csv')

df_raw = pd.concat([df_train, df_test], ignore_index=True, sort=False)

# %%
print("Row count:", df_raw.shape[0])
print("Column count:", df_raw.shape[1])
# Out:
# Row count: 13354
# Column count: 11

# %%
df_raw.sample(5)
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 8950   Jet Airways      24/03/2019   Kolkata    Banglore
# 7347      SpiceJet      27/03/2019   Kolkata    Banglore
# 12069    Air India      15/05/2019  Banglore       Delhi
# 5479   Jet Airways       3/05/2019  Banglore       Delhi
# 1353     Air India      01/03/2019  Banglore   New Delhi
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 8950         CCU → BOM → BLR    18:55  18:10 25 Mar  23h 15m      1 stop
# 7347               CCU → BLR    09:00         11:30   2h 30m    non-stop
# 12069              BLR → DEL    17:00         19:45   2h 45m    non-stop
# 5479               BLR → DEL    11:10         14:05   2h 55m    non-stop
# 1353   BLR → BOM → IDR → DEL    06:45  11:10 02 Mar  28h 25m     2 stops
#
#                    Additional_Info    Price
# 8950   In-flight meal not included  11134.0
# 7347                       No info   3847.0
# 12069                      No info      NaN
# 5479   In-flight meal not included   4030.0
# 1353                       No info  20999.0

# %%
#Check for Nulls & Data Types
df_raw.isnull().sum()
# Out:
# Airline               0
# Date_of_Journey       0
# Source                0
# Destination           0
# Route                 1
# Dep_Time              0
# Arrival_Time          0
# Duration              0
# Total_Stops           1
# Additional_Info       0
# Price              2671
# dtype: int64

# %%
df_raw.dtypes
# Out:
# Airline             object
# Date_of_Journey     object
# Source              object
# Destination         object
# Route               object
# Dep_Time            object
# Arrival_Time        object
# Duration            object
# Total_Stops         object
# Additional_Info     object
# Price              float64
# dtype: object

# %%
#Target Feature (Price) Analysis
fig,axes=plt.subplots(figsize=(12, 3))
ax = sns.histplot(df_raw['Price'].values, bins=150).set_title('Price')
df_raw[['Price']].describe().T
# Out:
#          count         mean          std     min     25%     50%      75%  \
# Price  10683.0  9087.064121  4611.359167  1759.0  5277.0  8372.0  12373.0
#
#            max
# Price  79512.0

# %%
fig,axes=plt.subplots(figsize=(12, 3))
ax = sns.boxplot(x=df_raw['Price'].values).set_title('Price')

# %%
#From Histrogram and Boxplot, clearly there are **outliers heavily skewing flight price data.
#Prices are right skewed by large outliers (20k to 80k price points).

# %%
#Visualize Price without Outliers
print("Number of outliers above 30k:", len(df_raw[df_raw['Price'] > 30000]))
# Out:
# Number of outliers above 30k: 24

# %%
df_no_out = df_raw[df_raw['Price'] < 30000]

fig,axes=plt.subplots(figsize=(12, 3))
ax = sns.histplot(df_no_out['Price'].values, bins=150).set_title('Price')
plt.xticks([int(x) for x in np.linspace(start=3000,stop=30000,num=10)])
#df_no_out.describe().round(2)
df_no_out[['Price']].describe().T
# Out:
#          count         mean          std     min     25%     50%      75%  \
# Price  10659.0  9012.081434  4294.485874  1759.0  5264.0  8372.0  12373.0
#
#            max
# Price  29528.0

# %%
#Mean decreased from $9087 to $9012, and SD decreased from $4611 to $4294 when examining without outliers
#We see that prices mainly hover around $5k to $7k and $13k to $14k.

# %%
#Investigate all elements for each feature
for column in df_raw:
    try:
        unique_vals = np.unique(df_raw[column])
    except:
        unique_vals = df_raw[column].unique()
        
    nr_values = len(unique_vals)
    if nr_values < 15:
        print('The number of values for {}: {} -- {}'.format(column, nr_values,unique_vals))
    else:
        print('The number of values for {}: {}'.format(column, nr_values))
# Out:
# The number of values for Airline: 12 -- ['Air Asia' 'Air India' 'GoAir' 'IndiGo' 'Jet Airways'
#  'Jet Airways Business' 'Multiple carriers'
#  'Multiple carriers Premium economy' 'SpiceJet' 'Trujet' 'Vistara'
#  'Vistara Premium economy']
# The number of values for Date_of_Journey: 44
# The number of values for Source: 5 -- ['Banglore' 'Chennai' 'Delhi' 'Kolkata' 'Mumbai']
# The number of values for Destination: 6 -- ['Banglore' 'Cochin' 'Delhi' 'Hyderabad' 'Kolkata' 'New Delhi']
# The number of values for Route: 133
# The number of values for Dep_Time: 223
# The number of values for Arrival_Time: 1451
# The number of values for Duration: 374
# The number of values for Total_Stops: 6 -- ['non-stop' '2 stops' '1 stop' '3 stops' nan '4 stops']
# The number of values for Additional_Info: 10 -- ['1 Long layover' '1 Short layover' '2 Long layover' 'Business class'
#  'Change airports' 'In-flight meal not included' 'No Info'
#  'No check-in baggage included' 'No info' 'Red-eye flight']
# The number of values for Price: 1871

# %%
#We can see that there are 12 airlines and 2 of them are 'business' and 'premium' class, might explain the outliers for flight prices.
#Data cleaning like fixing proper data types are required for Total_Stops, Additional_Info and Dep/Arrival Time columns.
#Categorical features such as Route will require some feature engineering to take into consideration the different possible combination of travel.

# %%
#Pre-Feature Engineering
df_feat = df_raw.copy()

# %%
## fixing data types

# converting to datetime type and getting the day of week
df_feat['Date_of_Journey'] = pd.to_datetime(df_feat['Date_of_Journey'], format='%d/%m/%Y')
df_feat['Weekday'] = pd.Series(df_feat['Date_of_Journey']).dt.day_name()

# converting to time type only 
df_feat['Dep_Time'] = pd.to_datetime(df_feat['Dep_Time'], format='%H:%M')
df_feat['Arrival_Time'] = df_feat['Arrival_Time'].str.split(' ').str[0]
df_feat['Arrival_Time'] = pd.to_datetime(df_feat['Arrival_Time'], format='%H:%M').dt.time

# getting hour,day,month from time
df_feat['Dep_Hr'] = df_feat['Dep_Time'].dt.hour.astype('int')
df_feat['Dep_Day'] = df_feat['Date_of_Journey'].dt.day.astype('int')
df_feat['Dep_Month'] = df_feat['Date_of_Journey'].dt.month.astype('int')

#df_feat['Dep_Hr'] = df_feat['Dep_Hr'].astype('int')
df_feat['Dep_Time'] = pd.to_datetime(df_feat['Dep_Time'], format='%H:%M').dt.time #changing to only time type

# Changing Duration feature from HH:MM to total minutes
hour = pd.to_numeric(df_feat['Duration'].str.replace(r'\D+', ' ', regex=True).str.split(' ').str[0])*60
mins = pd.to_numeric(df_feat['Duration'].str.replace(r'\D+', ' ', regex=True).str.split(' ').str[1])

# some rows dont have mins. hence will become NaN if add hr and min columns tgt. 
df_feat['Duration_min'] = np.where(mins.isnull(), hour, hour + mins )

# chaning total_stops to numeric
df_feat.drop(df_feat.index[9039], inplace=True)
df_feat["Total_Stops"] = np.where(df_feat["Total_Stops"] == "non-stop",0,
                         np.where(df_feat["Total_Stops"] == "1 stop",1,
                         np.where(df_feat["Total_Stops"] == "2 stops",2,
                         np.where(df_feat["Total_Stops"] == "3 stops",3,
                         np.where(df_feat["Total_Stops"] == "4 stops",4,0)))))

# %%
#Changing Date_of_Journey, Dep_Time, Arrival_Time to Datetime data type.
#Getting the Day of week from Date_of_Journey. (Mon, Tues, Wed etc.)
#Getting hour, day and month of travel from Date_of_Journey.
#Changing Duration from HH:MM (string) to total minutes (numerical) travelled.
#Changing Total_Stops from string to numerical (ordinal) type.

# %%
 #EDA
#Transaction Count and Price (Airline Breakdown)
airline_price_stats = df_feat.groupby('Airline')['Price'].describe()
airline_price_stats.sort_values(by=['count'], ascending=False)
# Out:
#                                     count          mean           std  \
# Airline
# Jet Airways                        3849.0  11643.923357   4258.940578
# IndiGo                             2053.0   5673.682903   2264.142168
# Air India                          1751.0   9612.427756   3901.734561
# Multiple carriers                  1196.0  10902.678094   3721.234997
# SpiceJet                            818.0   4338.284841   1849.922514
# Vistara                             479.0   7796.348643   2914.298578
# Air Asia                            319.0   5590.260188   2027.362290
# GoAir                               194.0   5861.056701   2703.585767
# Multiple carriers Premium economy    13.0  11418.846154   1717.153936
# Jet Airways Business                  6.0  58358.666667  11667.596748
# Vistara Premium economy               3.0   8962.333333   2915.405518
# Trujet                                1.0   4140.000000           NaN
#
#                                        min      25%      50%       75%  \
# Airline
# Jet Airways                         1840.0   9134.0  11467.0  14151.00
# IndiGo                              2227.0   4226.0   5000.0   6494.00
# Air India                           2050.0   6891.0   9443.0  12219.00
# Multiple carriers                   5797.0   7723.0  10197.0  13587.00
# SpiceJet                            1759.0   3574.5   3873.0   4760.00
# Vistara                             3687.0   5403.0   7980.0   9345.00
# Air Asia                            3383.0   4282.0   5162.0   6451.00
# GoAir                               3398.0   3898.0   5135.0   6811.25
# Multiple carriers Premium economy   9845.0  10161.0  11269.0  11269.00
# Jet Airways Business               46490.0  52243.0  54747.0  61122.50
# Vistara Premium economy             5969.0   7547.0   9125.0  10459.00
# Trujet                              4140.0   4140.0   4140.0   4140.00
#
#                                        max
# Airline
# Jet Airways                        54826.0
# IndiGo                             22153.0
# Air India                          31945.0
# Multiple carriers                  36983.0
# SpiceJet                           23267.0
# Vistara                            21730.0
# Air Asia                           13774.0
# GoAir                              22794.0
# Multiple carriers Premium economy  14629.0
# Jet Airways Business               79512.0
# Vistara Premium economy            11793.0
# Trujet                              4140.0

# %%
airline_order = airline_price_stats.sort_values(by=['count'], ascending=False).index
sns.set(rc={'figure.figsize':(12,6)})
sns.boxplot(data=df_feat, x="Price", y="Airline",order=airline_order)
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Airline'>

# %%
#differences in price points among the different airlines can be onbserved.
#Espically IndiGo and SpiceJet that has significantly lower prices.
#We can observe that the more expensive prices are from the Business and Premium Airlines but also with little data on them

# %%
#Price breakdown by Total_Stops
sns.set(rc={'figure.figsize':(12,3)})
stop_order = [int(x) for x in np.linspace(start=0,stop=4,num=5)]
stop_order = [str(i) for i in stop_order]
sns.boxplot(data=df_feat, x="Price", y=df_feat["Total_Stops"].astype('string'), order=stop_order)
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Total_Stops'>

# %%
#Clearly direct flights with 0 stops are significantly cheaper.
#We can also observe that the more number of stops, the more expensive the flight price is

# %%
#Correlation between Duration & Price
sns.set(rc={'figure.figsize':(12,5)})
sns.regplot(data=df_feat[df_feat['Price'] < 25000], x='Duration_min', y='Price',
            line_kws = {"color": "red"})
# Out:
# <AxesSubplot:xlabel='Duration_min', ylabel='Price'>

# %%
#We do see a slight positive correlation between flight duration and price.
#Outliers above 25k were removed in this analysis.

# %%
#Price breakdown by Time/Date Types
#Breakdown by Hours of the day

# %%
dep_order = [int(x) for x in np.linspace(start=1,stop=23,num=23)]
dep_order = [str(i) for i in dep_order]
sns.boxplot(data=df_feat, x="Price", y=df_feat["Dep_Hr"].astype('string'), order=dep_order)
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Dep_Hr'>

# %%
#Breakdown by Days of the Month
sns.set(rc={'figure.figsize':(12,4)})
dep_order = np.sort(df_feat["Dep_Day"].unique()).tolist()
dep_order = [str(i) for i in dep_order]
sns.boxplot(data=df_feat, x="Price", y=df_feat["Dep_Day"].astype('string'), order=dep_order)
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Dep_Day'>

# %%
#Breakdown by Months of the Year
sns.set(rc={'figure.figsize':(12,3)})
dep_order = np.sort(df_feat["Dep_Month"].unique()).tolist()
dep_order = [str(i) for i in dep_order]
sns.boxplot(data=df_feat, x="Price", y=df_feat["Dep_Month"].astype('string'), order=dep_order)
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Dep_Month'>

# %%
#Price by "Additional Info" Breakdown
airline_price_stats = df_feat.groupby('Additional_Info')['Price'].describe()
airline_price_stats.sort_values(by=['count'], ascending=False)
# Out:
#                                count          mean           std      min  \
# Additional_Info
# No info                       8344.0   9141.519295   4714.347572   1759.0
# In-flight meal not included   1982.0   9471.834511   2812.043362   1840.0
# No check-in baggage included   320.0   3645.156250    865.712619   1965.0
# 1 Long layover                  19.0  22109.631579   8040.051155   7744.0
# Change airports                  7.0  16800.714286   4449.728371  13366.0
# Business class                   4.0  56811.250000  21381.667044  28097.0
# No Info                          3.0   8044.666667    119.181934   7917.0
# 1 Short layover                  1.0  26743.000000           NaN  26743.0
# 2 Long layover                   1.0  26480.000000           NaN  26480.0
# Red-eye flight                   1.0  10873.000000           NaN  10873.0
#
#                                   25%      50%       75%      max
# Additional_Info
# No info                        5224.0   8016.0  12970.00  54826.0
# In-flight meal not included    7757.0  10262.0  10844.00  19644.0
# No check-in baggage included   3543.0   3841.0   3859.00   6356.0
# 1 Long layover                14673.0  25735.0  27992.00  31825.0
# Change airports               13940.5  15119.0  17573.50  26092.0
# Business class                49931.0  59818.0  66698.25  79512.0
# No Info                        7990.5   8064.0   8108.50   8153.0
# 1 Short layover               26743.0  26743.0  26743.00  26743.0
# 2 Long layover                26480.0  26480.0  26480.00  26480.0
# Red-eye flight                10873.0  10873.0  10873.00  10873.0

# %%
info_order = airline_price_stats.sort_values(by=['count'], ascending=False).index.tolist()
sns.set(rc={'figure.figsize':(12,3)})
sns.boxplot(data=df_feat, x="Price", y=df_feat["Additional_Info"].astype('string'), order = info_order)
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Additional_Info'>

# %%
#We can observe that flight prices are generally cheaper when there are no info

# %%
sns.set(rc={'figure.figsize':(12,3)})
date_count = df_feat[df_feat['Price'].notnull()].groupby('Date_of_Journey').count().reset_index()
g = sns.lineplot(data=date_count, x="Date_of_Journey", y="Airline")
g.set_title('Daily Number of flight transactions trend')
g.set_ylabel('No of Airline Transactions')

print('total flight transactions:' ,len(df_feat[df_feat['Price'].notnull()]))
# Out:
# total flight transactions: 10682

# %%
sns.set(rc={'figure.figsize':(12,3)})
avg_price_time = df_feat[df_feat['Airline'] != 'Jet Airways Business'].groupby('Date_of_Journey').mean('Price').reset_index()
g = sns.lineplot(x="Date_of_Journey", y="Price", data=avg_price_time)
g.set_title('Daily Average Price trend')
# Out:
# Text(0.5, 1.0, 'Daily Average Price trend')

# %%
#Daily Average Flight Price (Airline Breakdown)
sns.set(rc={'figure.figsize':(9,3)})
sns.set(font_scale=0.8)
avg_air_price_time = df_feat.groupby(['Airline','Date_of_Journey']).mean('Price').reset_index()
sns.lineplot(x="Date_of_Journey", y="Price", hue='Airline', data=avg_air_price_time[avg_air_price_time['Airline'] != 'Jet Airways Business'])
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
#Analyzing most common route (DEL → XXX → COK)
#To understand if difference between flight stops locations will difference in prices.
#For example, if DEL → AMD → COK will be more/less expensive than DEL → PNQ → COK.
#We will analyze the most common route from DEL to COK.
df_feat['Route'].value_counts().head(5)
# Out:
# DEL → BOM → COK    3000
# BLR → DEL          1941
# CCU → BOM → BLR    1232
# CCU → BLR           896
# BOM → HYD           785
# Name: Route, dtype: int64

# %%
stops3 = df_feat[(df_feat['Source'] == 'Delhi') & (df_feat['Destination'] == 'Cochin') & (df_feat['Total_Stops']==1)]
stops3 = stops3.groupby('Route')[['Price', 'Duration_min']].mean().reset_index().sort_values('Price')
stops3
# Out:
#              Route         Price  Duration_min
# 0  DEL → AMD → COK   5606.200000    376.333333
# 7  DEL → PNQ → COK   6602.071429    279.285714
# 5  DEL → LKO → COK   7166.176471    329.782609
# 4  DEL → HYD → COK   7299.331288    576.143552
# 6  DEL → MAA → COK   7312.431507    756.315789
# 2  DEL → BLR → COK   7559.612069    605.313589
# 8  DEL → TRV → COK   7835.625000   1409.500000
# 3  DEL → BOM → COK  10954.205808    735.758333
# 1  DEL → BBI → COK  11062.600000    355.000000

# %%
#Seems like the inter stop between Del & Cok does have a difference in flight price
#Important to take note of the inter stops between departure and destination in our prediction model

# %%
df_post = df_feat[['Airline', 'Source', 'Destination', 'Route', 'Total_Stops', 
                   'Additional_Info', 'Dep_Hr','Dep_Day','Dep_Month', 'Weekday', 'Duration_min', 'Price']]

# %%
df_post.sample(5)
# Out:
#            Airline   Source Destination                  Route  Total_Stops  \
# 3518   Jet Airways    Delhi      Cochin  DEL → JAI → BOM → COK            2
# 8455        IndiGo    Delhi      Cochin        DEL → BOM → COK            1
# 11557       IndiGo  Chennai     Kolkata              MAA → CCU            0
# 7050   Jet Airways    Delhi      Cochin  DEL → BDQ → BOM → COK            2
# 6371        IndiGo    Delhi      Cochin        DEL → BOM → COK            1
#
#       Additional_Info  Dep_Hr  Dep_Day  Dep_Month    Weekday  Duration_min  \
# 3518          No info       5       24          6     Monday        1375.0
# 8455          No info      10       12          6  Wednesday         895.0
# 11557         No info      14       21          3   Thursday         145.0
# 7050          No info      10       21          3   Thursday         485.0
# 6371          No info       9        9          6     Sunday         975.0
#
#          Price
# 3518   13014.0
# 8455    5883.0
# 11557      NaN
# 7050   11360.0
# 6371    6628.0

# %%
#Route into individual columns
df_post.head(5)
# Out:
#        Airline    Source Destination                  Route  Total_Stops  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL            0
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR            2
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK            2
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR            1
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL            1
#
#   Additional_Info  Dep_Hr  Dep_Day  Dep_Month    Weekday  Duration_min  \
# 0         No info      22       24          3     Sunday         170.0
# 1         No info       5        1          5  Wednesday         445.0
# 2         No info       9        9          6     Sunday        1140.0
# 3         No info      18       12          5     Sunday         325.0
# 4         No info      16        1          3     Friday         285.0
#
#      Price
# 0   3897.0
# 1   7662.0
# 2  13882.0
# 3   6218.0
# 4  13302.0

# %%
df_post[['Route1', 'Route2', 'Route3', 'Route4', 'Route5', 'Route6' ]] = df_post['Route'].str.split('→', expand=True)

# %%
# keeping route2 to route5
df_post['Route2'] = np.where(df_post['Total_Stops'] == 0, None, df_post['Route2'])
df_post['Route3'] = np.where(df_post['Total_Stops'] == 1, None, df_post['Route3'])
df_post['Route4'] = np.where(df_post['Total_Stops'] == 2, None, df_post['Route4'])
df_post['Route5'] = np.where(df_post['Total_Stops'] == 3, None, df_post['Route5'])
df_post['Route6'] = np.where(df_post['Total_Stops'] == 4, None, df_post['Route6'])
df_post = df_post.drop(['Route1', 'Route6'], axis=1)

# %%
df_post[['Route', 'Total_Stops', 'Route2', 'Route3', 'Route4', 'Route5']][df_post['Total_Stops']==4].sample(2)
# Out:
#                                    Route  Total_Stops Route2 Route3 Route4  \
# 13105  BLR → CCU → BBI → HYD → VGA → DEL            4   CCU    BBI    HYD
# 9182   BLR → CCU → BBI → HYD → VGA → DEL            4   CCU    BBI    HYD
#
#       Route5
# 13105   VGA
# 9182    VGA

# %%
#In this step we are splitting the "Route" Column into 6 columns (Route1 to Route 6)
#As the highest number of stops is 6, including depature and destination stop we have 6 columns
#However, since there are columns 'Depature' and 'Destination', we will then drop Route1 and Route6 which represents thte same.

# %%
route_top15 = df_post['Route'].value_counts().head(15).index.tolist()

# %%
df_post['Route'] = df_post['Route'].apply(lambda i: i if i in route_top15 else 'Others')

# %%
df_post.sample(5)
# Out:
#                 Airline  Source Destination            Route  Total_Stops  \
# 5239        Jet Airways  Mumbai   Hyderabad        BOM → HYD            0
# 2343          Air India   Delhi      Cochin           Others            2
# 2197  Multiple carriers   Delhi      Cochin  DEL → BOM → COK            1
# 9184  Multiple carriers   Delhi      Cochin  DEL → BOM → COK            1
# 3829  Multiple carriers   Delhi      Cochin  DEL → BOM → COK            1
#
#                   Additional_Info  Dep_Hr  Dep_Day  Dep_Month    Weekday  \
# 5239  In-flight meal not included       2       24          6     Monday
# 2343                      No info       9       15          5  Wednesday
# 2197                      No info       8       27          3  Wednesday
# 9184                      No info      10       21          5    Tuesday
# 3829  In-flight meal not included       7        1          6   Saturday
#
#       Duration_min    Price Route2 Route3 Route4 Route5
# 5239          85.0   4050.0   None   None   None   None
# 2343        1420.0  10975.0   HYD    MAA    None   None
# 2197         450.0  12537.0   BOM    None   None   None
# 9184         910.0   7485.0   BOM    None   None   None
# 3829         730.0  12927.0   BOM    None   None   None

# %%
#Get dummies for categorical feature
df_final = pd.get_dummies(df_post, columns = ['Airline', 'Source', 'Destination', 
                                               'Additional_Info', 'Weekday'], drop_first=True)
df_final = df_final.drop(['Route'], axis=1)

# %%
df_final.sample(3)
# Out:
#       Total_Stops  Dep_Hr  Dep_Day  Dep_Month  Duration_min    Price Route2  \
# 3171            1       4        9          3         535.0  16259.0   BOM
# 6012            1      21       12          5         775.0   8586.0   BOM
# 3805            2       5       24          6        1375.0  13292.0   IDR
#
#      Route3 Route4 Route5  Airline_Air India  Airline_GoAir  Airline_IndiGo  \
# 3171   None   None   None                  0              0               0
# 6012   None   None   None                  0              0               0
# 3805   BOM    None   None                  0              0               0
#
#       Airline_Jet Airways  Airline_Jet Airways Business  \
# 3171                    0                             0
# 6012                    1                             0
# 3805                    1                             0
#
#       Airline_Multiple carriers  Airline_Multiple carriers Premium economy  \
# 3171                          1                                          0
# 6012                          0                                          0
# 3805                          0                                          0
#
#       Airline_SpiceJet  Airline_Trujet  Airline_Vistara  \
# 3171                 0               0                0
# 6012                 0               0                0
# 3805                 0               0                0
#
#       Airline_Vistara Premium economy  Source_Chennai  Source_Delhi  \
# 3171                                0               0             1
# 6012                                0               0             0
# 3805                                0               0             1
#
#       Source_Kolkata  Source_Mumbai  Destination_Cochin  Destination_Delhi  \
# 3171               0              0                   1                  0
# 6012               1              0                   0                  0
# 3805               0              0                   1                  0
#
#       Destination_Hyderabad  Destination_Kolkata  Destination_New Delhi  \
# 3171                      0                    0                      0
# 6012                      0                    0                      0
# 3805                      0                    0                      0
#
#       Additional_Info_1 Short layover  Additional_Info_2 Long layover  \
# 3171                                0                               0
# 6012                                0                               0
# 3805                                0                               0
#
#       Additional_Info_Business class  Additional_Info_Change airports  \
# 3171                               0                                0
# 6012                               0                                0
# 3805                               0                                0
#
#       Additional_Info_In-flight meal not included  Additional_Info_No Info  \
# 3171                                            0                        0
# 6012                                            1                        0
# 3805                                            0                        0
#
#       Additional_Info_No check-in baggage included  Additional_Info_No info  \
# 3171                                             0                        1
# 6012                                             0                        0
# 3805                                             0                        1
#
#       Additional_Info_Red-eye flight  Weekday_Monday  Weekday_Saturday  \
# 3171                               0               0                 1
# 6012                               0               0                 0
# 3805                               0               1                 0
#
#       Weekday_Sunday  Weekday_Thursday  Weekday_Tuesday  Weekday_Wednesday
# 3171               0                 0                0                  0
# 6012               1                 0                0                  0
# 3805               0                 0                0                  0

# %%
print("Row count:", df_final.shape[0])
print("Column count:", df_final.shape[1])
# Out:
# Row count: 13353
# Column count: 45

# %%
#After feature enginnering and get dummies, our initial dataset columns increased from 11 columns to 45 columns.

# %%
#'Route' Label Encoding
route2_dict = {}
count=0
for i in df_final['Route2'].unique():
    route2_dict[i] = count
    count+=1
    
route3_dict = {}
count=0
for i in df_final['Route3'].unique():
    route3_dict[i] = count
    count+=1
    
for k,v in route3_dict.items():
    if k not in route2_dict:
        route2_dict[k] = v

# %%
df_final["Route2"] = df_final["Route2"].map(route2_dict)
df_final["Route3"] = df_final["Route3"].map(route2_dict)
df_final["Route4"] = df_final["Route4"].map(route2_dict)
df_final["Route5"] = df_final["Route5"].map(route2_dict)

# %%
df_final[['Total_Stops', 'Route2', 'Route3', 'Route4', 'Route5']][df_final['Total_Stops']==4].sample(2)
# Out:
#        Total_Stops  Route2  Route3  Route4  Route5
# 9182             4       8      19      13      28
# 13105            4       8      19      13      28

# %%
#Correlation between features and target feature
corr = df_final.corrwith(df_final['Price']).sort_values(ascending = False).to_frame()
corr.columns = ['Correlations']
plt.subplots(figsize = (5,10))
sns.heatmap(corr,annot = True,linewidths = 0.4,linecolor = 'black');
plt.title('Correlation with Price');

# %%
df_final.sample(5)
# Out:
#       Total_Stops  Dep_Hr  Dep_Day  Dep_Month  Duration_min    Price  Route2  \
# 6363            0      14        6          4         150.0   3873.0       0
# 8705            0      18       24          6         185.0   5201.0       0
# 6929            1      19       12          6         265.0   3574.0      13
# 9088            1      11        9          5         455.0   8266.0       4
# 9530            2      23        9          5        1760.0  15129.0       6
#
#       Route3  Route4  Route5  Airline_Air India  Airline_GoAir  \
# 6363       0       0       0                  0              0
# 8705       0       0       0                  1              0
# 6929       0       0       0                  0              0
# 9088       0       0       0                  0              0
# 9530       4       0       0                  0              0
#
#       Airline_IndiGo  Airline_Jet Airways  Airline_Jet Airways Business  \
# 6363               0                    0                             0
# 8705               0                    0                             0
# 6929               1                    0                             0
# 9088               0                    0                             0
# 9530               0                    1                             0
#
#       Airline_Multiple carriers  Airline_Multiple carriers Premium economy  \
# 6363                          0                                          0
# 8705                          0                                          0
# 6929                          0                                          0
# 9088                          1                                          0
# 9530                          0                                          0
#
#       Airline_SpiceJet  Airline_Trujet  Airline_Vistara  \
# 6363                 1               0                0
# 8705                 0               0                0
# 6929                 0               0                0
# 9088                 0               0                0
# 9530                 0               0                0
#
#       Airline_Vistara Premium economy  Source_Chennai  Source_Delhi  \
# 6363                                0               0             0
# 8705                                0               0             1
# 6929                                0               0             0
# 9088                                0               0             1
# 9530                                0               0             1
#
#       Source_Kolkata  Source_Mumbai  Destination_Cochin  Destination_Delhi  \
# 6363               1              0                   0                  0
# 8705               0              0                   1                  0
# 6929               1              0                   0                  0
# 9088               0              0                   1                  0
# 9530               0              0                   1                  0
#
#       Destination_Hyderabad  Destination_Kolkata  Destination_New Delhi  \
# 6363                      0                    0                      0
# 8705                      0                    0                      0
# 6929                      0                    0                      0
# 9088                      0                    0                      0
# 9530                      0                    0                      0
#
#       Additional_Info_1 Short layover  Additional_Info_2 Long layover  \
# 6363                                0                               0
# 8705                                0                               0
# 6929                                0                               0
# 9088                                0                               0
# 9530                                0                               0
#
#       Additional_Info_Business class  Additional_Info_Change airports  \
# 6363                               0                                0
# 8705                               0                                0
# 6929                               0                                0
# 9088                               0                                0
# 9530                               0                                0
#
#       Additional_Info_In-flight meal not included  Additional_Info_No Info  \
# 6363                                            0                        0
# 8705                                            0                        0
# 6929                                            0                        0
# 9088                                            0                        0
# 9530                                            0                        0
#
#       Additional_Info_No check-in baggage included  Additional_Info_No info  \
# 6363                                             0                        1
# 8705                                             0                        1
# 6929                                             0                        1
# 9088                                             0                        1
# 9530                                             0                        1
#
#       Additional_Info_Red-eye flight  Weekday_Monday  Weekday_Saturday  \
# 6363                               0               0                 1
# 8705                               0               1                 0
# 6929                               0               0                 0
# 9088                               0               0                 0
# 9530                               0               0                 0
#
#       Weekday_Sunday  Weekday_Thursday  Weekday_Tuesday  Weekday_Wednesday
# 6363               0                 0                0                  0
# 8705               0                 0                0                  0
# 6929               0                 0                0                  1
# 9088               0                 1                0                  0
# 9530               0                 1                0                  0

# %%
#Train Test Split
df_final = df_final[df_final['Price'].notnull()]

X = df_final.drop(['Price'], axis=1)
y = df_final['Price'].copy()
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state=42)

# Scale the input features
scaler = StandardScaler()

lasso = LassoCV(cv=5)
lasso.fit(X_train, y_train)

print(len(X_train.columns))
selected_features = X_train.columns[lasso.coef_ != 0]
print(len(selected_features))

X_train_selected = X_train.loc[:, selected_features]
X_train_scaled = scaler.fit_transform(X_train_selected)

X_test_selected = X_test.loc[:, selected_features]
X_test_scaled = scaler.transform(X_test_selected)

# Fit a lasso regression model using cross-validation
lasso = LassoCV(cv=5)
lasso.fit(X_train_scaled, y_train)

# Select the best alpha value
best_alpha = lasso.alpha_

# Fit the final model using the selected features
final_model = Lasso(alpha=best_alpha)
final_model.fit(X_train_scaled, y_train)

# Evaluate the performance of the final model on the test data
y_pred = final_model.predict(X_test_scaled)
mse = mean_squared_error(y_test, y_pred)

print("Test MSE:", mse)
# Out:
# 44
# 3
# Test MSE: 13737023.865061713

# %%
#Base Models
models = []
rmse_lst = []
mse_lst = []
r2_lst = []

# %%
dummy_reg = DummyRegressor(strategy='mean')
dummy_reg.fit(X_train, y_train)
y_pred = dummy_reg.predict(X_test)

rmse = float(format(np.sqrt(mean_squared_error(y_test, y_pred)), '.3f'))
print("RMSE: ", rmse)
mse = float(format(mean_squared_error(y_test, y_pred), '.3f'))
print("MSE: ", mse)
r2 = float(format(r2_score(y_test, y_pred), '.3f'))
print("R2: ", r2)


models.append('Dumb')
rmse_lst.append(rmse)
mse_lst.append(mse)
r2_lst.append(r2)
# Out:
# RMSE:  4482.259
# MSE:  20090642.916
# R2:  -0.001

# %%
#Linear Regression
lr = LinearRegression()
lr.fit(X_train, y_train)

#Evalute th models on the test and training data
y_lr_pred = lr.predict(X_test)
y_lr_train_pred = lr.predict(X_train)

rmse = float(format(np.sqrt(mean_squared_error(y_test, y_lr_pred)), '.3f'))
print("RMSE: ", rmse)
mse = float(format(mean_squared_error(y_test, y_lr_pred), '.3f'))
print("MSE: ", mse)
r2 = float(format(r2_score(y_test, y_lr_pred), '.3f'))
print("R2: ", r2)

rmse = float(format(np.sqrt(mean_squared_error(y_train, y_lr_train_pred)), '.3f'))
print("RMSE: ", rmse)
mse = float(format(mean_squared_error(y_train, y_lr_train_pred), '.3f'))
print("MSE: ", mse)
r2 = float(format(r2_score(y_train, y_lr_train_pred), '.3f'))
print("R2: ", r2)

models.append('Linear Regression')
rmse_lst.append(rmse)
mse_lst.append(mse)
r2_lst.append(r2)
# Out:
# RMSE:  2412.503
# MSE:  5820172.785
# R2:  0.71
# RMSE:  2548.299
# MSE:  6493826.489
# R2:  0.703

# %%
# Ridge Regression
rr = Ridge(alpha=0.5)
rr.fit(X_train, y_train)

#Evalute th models on the test and training data
y_rr_pred = rr.predict(X_test)
y_rr_train_pred = rr.predict(X_train)

rmse = float(format(np.sqrt(mean_squared_error(y_test, y_rr_pred)), '.3f'))
print("RMSE: ", rmse)
mse = float(format(mean_squared_error(y_test, y_rr_pred), '.3f'))
print("MSE: ", mse)
r2 = float(format(r2_score(y_test, y_rr_pred), '.3f'))
print("R2: ", r2)

rmse = float(format(np.sqrt(mean_squared_error(y_train, y_rr_train_pred)), '.3f'))
print("RMSE: ", rmse)
mse = float(format(mean_squared_error(y_train, y_rr_train_pred), '.3f'))
print("MSE: ", mse)
r2 = float(format(r2_score(y_train, y_rr_train_pred), '.3f'))
print("R2: ", r2)

models.append('Ridge Regression')
rmse_lst.append(rmse)
mse_lst.append(mse)
r2_lst.append(r2)
# Out:
# RMSE:  2408.27
# MSE:  5799764.685
# R2:  0.711
# RMSE:  2550.61
# MSE:  6505613.541
# R2:  0.702

# %%
#Random forest regression
rfr = RandomForestRegressor(n_estimators = 100, random_state = 0)
rfr.fit(X_train, y_train)  
y_pred = rfr.predict(X_test)

rmse = float(format(np.sqrt(mean_squared_error(y_test, y_pred)), '.3f'))
print("RMSE: ", rmse)
mse = float(format(mean_squared_error(y_test, y_pred), '.3f'))
print("MSE: ", mse)
r2 = float(format(r2_score(y_test, y_pred), '.3f'))
print("R2: ", r2)

models.append('Random Forest')
rmse_lst.append(rmse)
mse_lst.append(mse)
r2_lst.append(r2)
# Out:
# RMSE:  1447.606
# MSE:  2095562.81
# R2:  0.896

# %%
rfr_importance = rfr.feature_importances_
rfr_names = rfr.feature_names_in_

rfr_import_df = pd.DataFrame({"feature_names" : rfr_names, 
                               "rfr_importances" : rfr_importance.round(3)})
rfr_import_df['rfr_impt_rank'] = rfr_import_df['rfr_importances'].rank(method='dense', ascending=False)

# %%
rfr_import_df.sort_values('rfr_importances', ascending=False).head(7)
# Out:
#                                   feature_names  rfr_importances  \
# 4                                  Duration_min            0.456
# 2                                       Dep_Day            0.084
# 33  Additional_Info_In-flight meal not included            0.076
# 13                 Airline_Jet Airways Business            0.067
# 12                          Airline_Jet Airways            0.057
# 3                                     Dep_Month            0.048
# 1                                        Dep_Hr            0.034
#
#     rfr_impt_rank
# 4             1.0
# 2             2.0
# 33            3.0
# 13            4.0
# 12            5.0
# 3             6.0
# 1             7.0

# %%
xgb = XGBRegressor()
xgb.fit(X_train, y_train)
y_pred = xgb.predict(X_test)

rmse = float(format(np.sqrt(mean_squared_error(y_test, y_pred)), '.3f'))
print("RMSE: ", rmse)
mse = float(format(mean_squared_error(y_test, y_pred), '.3f'))
print("MSE: ", mse)
r2 = float(format(r2_score(y_test, y_pred), '.3f'))
print("R2: ", r2)

models.append('XGBoost')
rmse_lst.append(rmse)
mse_lst.append(mse)
r2_lst.append(r2)
# Out:
# RMSE:  1365.164
# MSE:  1863673.999
# R2:  0.907

# %%
xgb_importance = xgb.feature_importances_
xgb_names = xgb.feature_names_in_

xgb_import_df = pd.DataFrame({"feature_names" : xgb_names, 
                               "xgb_importances" : xgb_importance.round(3)})
xgb_import_df['xgb_impt_rank'] = xgb_import_df['xgb_importances'].rank(method='dense', ascending=False)

# %%
xgb_import_df.sort_values('xgb_importances', ascending=False).head(7)
# Out:
#                                   feature_names  xgb_importances  \
# 13                 Airline_Jet Airways Business            0.586
# 12                          Airline_Jet Airways            0.068
# 33  Additional_Info_In-flight meal not included            0.057
# 4                                  Duration_min            0.040
# 28                        Destination_New Delhi            0.028
# 11                               Airline_IndiGo            0.023
# 0                                   Total_Stops            0.018
#
#     xgb_impt_rank
# 13            1.0
# 12            2.0
# 33            3.0
# 4             4.0
# 28            5.0
# 11            6.0
# 0             7.0

# %%
gbr = GradientBoostingRegressor(learning_rate=0.1, n_estimators=100, random_state=0)
gbr.fit(X_train, y_train)
y_pred = gbr.predict(X_test)
rmse = float(format(np.sqrt(mean_squared_error(y_test, y_pred)), '.3f'))
print("RMSE: ", rmse)
mse = float(format(mean_squared_error(y_test, y_pred), '.3f'))
print("MSE: ", mse)
r2 = float(format(r2_score(y_test, y_pred), '.3f'))
print("R2: ", r2)

models.append('Gradient Boost')
rmse_lst.append(rmse)
mse_lst.append(mse)
r2_lst.append(r2)
# Out:
# RMSE:  1707.201
# MSE:  2914534.923
# R2:  0.855

# %%
gbr_importance = gbr.feature_importances_
gbr_names = gbr.feature_names_in_

gbr_import_df = pd.DataFrame({"feature_names" : gbr_names, 
                               "gbr_importances" : gbr_importance.round(3)})
gbr_import_df['gbr_impt_rank'] = gbr_import_df['gbr_importances'].rank(method='dense', ascending=False)

# %%
gbr_import_df.sort_values('gbr_importances', ascending=False).head(7)
# Out:
#                                   feature_names  gbr_importances  \
# 4                                  Duration_min            0.484
# 2                                       Dep_Day            0.103
# 12                          Airline_Jet Airways            0.083
# 13                 Airline_Jet Airways Business            0.083
# 33  Additional_Info_In-flight meal not included            0.072
# 3                                     Dep_Month            0.041
# 6                                        Route3            0.029
#
#     gbr_impt_rank
# 4             1.0
# 2             2.0
# 12            3.0
# 13            3.0
# 33            4.0
# 3             5.0
# 6             6.0

# %%
data = {'models': models,
        'rmse': rmse_lst,
        'mse': mse_lst,
        'r2': r2_lst
        }

df_result_sum = pd.DataFrame(data)

# %%
df_result_sum
# Out:
#               models      rmse           mse     r2
# 0               Dumb  4482.259  2.009064e+07 -0.001
# 1  Linear Regression  2548.299  6.493826e+06  0.703
# 2   Ridge Regression  2550.610  6.505614e+06  0.702
# 3      Random Forest  1447.606  2.095563e+06  0.896
# 4            XGBoost  1365.164  1.863674e+06  0.907
# 5     Gradient Boost  1707.201  2.914535e+06  0.855

# %%
sum_import_df = rfr_import_df.merge(xgb_import_df,on='feature_names').merge(gbr_import_df,on='feature_names')
sum_import_df['overall_score'] = sum_import_df['rfr_impt_rank'] + sum_import_df['xgb_impt_rank'] + sum_import_df['gbr_impt_rank']
sum_import_df['overall_rank'] = sum_import_df['overall_score'].rank(method='dense', ascending=True)

# %%
sum_import_df.sort_values('overall_rank', ascending=True)[['feature_names', 'rfr_impt_rank', 'xgb_impt_rank', 'gbr_impt_rank', 'overall_score', 'overall_rank']]
# Out:
#                                    feature_names  rfr_impt_rank  \
# 4                                   Duration_min            1.0
# 13                  Airline_Jet Airways Business            4.0
# 33   Additional_Info_In-flight meal not included            3.0
# 12                           Airline_Jet Airways            5.0
# 2                                        Dep_Day            2.0
# 3                                      Dep_Month            6.0
# 28                         Destination_New Delhi            9.0
# 6                                         Route3           11.0
# 11                                Airline_IndiGo           15.0
# 14                     Airline_Multiple carriers           10.0
# 0                                    Total_Stops           12.0
# 5                                         Route2            8.0
# 1                                         Dep_Hr            7.0
# 10                                 Airline_GoAir           18.0
# 36                       Additional_Info_No info           15.0
# 9                              Airline_Air India           13.0
# 21                                  Source_Delhi           17.0
# 16                              Airline_SpiceJet           18.0
# 22                                Source_Kolkata           16.0
# 23                                 Source_Mumbai           17.0
# 31                Additional_Info_Business class           18.0
# 43                             Weekday_Wednesday           16.0
# 38                                Weekday_Monday           14.0
# 18                               Airline_Vistara           17.0
# 40                                Weekday_Sunday           16.0
# 42                               Weekday_Tuesday           19.0
# 32               Additional_Info_Change airports           19.0
# 41                              Weekday_Thursday           18.0
# 39                              Weekday_Saturday           17.0
# 25                             Destination_Delhi           19.0
# 34                       Additional_Info_No Info           20.0
# 30                Additional_Info_2 Long layover           19.0
# 26                         Destination_Hyderabad           17.0
# 24                            Destination_Cochin           17.0
# 19               Airline_Vistara Premium economy           20.0
# 29               Additional_Info_1 Short layover           19.0
# 20                                Source_Chennai           19.0
# 15     Airline_Multiple carriers Premium economy           20.0
# 27                           Destination_Kolkata           19.0
# 35  Additional_Info_No check-in baggage included           20.0
# 37                Additional_Info_Red-eye flight           20.0
# 8                                         Route5           20.0
# 7                                         Route4           20.0
# 17                                Airline_Trujet           20.0
#
#     xgb_impt_rank  gbr_impt_rank  overall_score  overall_rank
# 4             4.0            1.0            6.0           1.0
# 13            1.0            3.0            8.0           2.0
# 33            3.0            4.0           10.0           3.0
# 12            2.0            3.0           10.0           3.0
# 2            10.0            2.0           14.0           4.0
# 3            12.0            5.0           23.0           5.0
# 28            5.0            9.0           23.0           5.0
# 6            11.0            6.0           28.0           6.0
# 11            6.0            7.0           28.0           6.0
# 14            8.0           10.0           28.0           6.0
# 0             7.0           11.0           30.0           7.0
# 5            15.0            8.0           31.0           8.0
# 1            19.0           12.0           38.0           9.0
# 10            9.0           14.0           41.0          10.0
# 36           16.0           12.0           43.0          11.0
# 9            16.0           14.0           43.0          11.0
# 21           12.0           15.0           44.0          12.0
# 16           14.0           13.0           45.0          13.0
# 22           15.0           15.0           46.0          14.0
# 23           15.0           14.0           46.0          14.0
# 31           13.0           15.0           46.0          14.0
# 43           18.0           15.0           49.0          15.0
# 38           19.0           16.0           49.0          15.0
# 18           18.0           15.0           50.0          16.0
# 40           19.0           15.0           50.0          16.0
# 42           16.0           16.0           51.0          17.0
# 32           16.0           16.0           51.0          17.0
# 41           18.0           16.0           52.0          18.0
# 39           19.0           16.0           52.0          18.0
# 25           17.0           16.0           52.0          18.0
# 34           17.0           16.0           53.0          19.0
# 30           18.0           16.0           53.0          19.0
# 26           21.0           15.0           53.0          19.0
# 24           21.0           15.0           53.0          19.0
# 19           18.0           16.0           54.0          20.0
# 29           19.0           16.0           54.0          20.0
# 20           20.0           16.0           55.0          21.0
# 15           20.0           16.0           56.0          22.0
# 27           21.0           16.0           56.0          22.0
# 35           20.0           16.0           56.0          22.0
# 37           20.0           16.0           56.0          22.0
# 8            21.0           16.0           57.0          23.0
# 7            21.0           16.0           57.0          23.0
# 17           21.0           16.0           57.0          23.0

# %%
#Here we sum up all the rank score for each feature across the different models
#The lower the rank score, the better the feature is.
#We are see that generally the different models are assigning around the same importance to each features.

# %%
#Hyper Parameter Tunning
#Random Forest
n_estimators = [int(x) for x in np.linspace(start=900,stop=1400,num=6)] # Number of trees in random forest
max_features = ['auto', 'sqrt'] # Number of features to consider at every split
max_depth = [int(x) for x in np.linspace(30, 70, num = 6)] # Max number of levels in tree
min_samples_split = [3,5,10,12,15,17,20] # Min number of samples required to split a node
min_samples_leaf = [1, 2, 5, 10] # Min number of samples requred at each leaft node

rf_param_grid = {
    
    'n_estimators': n_estimators,
    'max_features': max_features, 
    'max_depth': max_depth, 
    'min_samples_split': min_samples_split,
    'min_samples_leaf': min_samples_leaf,
}

print(rf_param_grid)
# Out:
# {'n_estimators': [900, 1000, 1100, 1200, 1300, 1400], 'max_features': ['auto', 'sqrt'], 'max_depth': [30, 38, 46, 54, 62, 70], 'min_samples_split': [3, 5, 10, 12, 15, 17, 20], 'min_samples_leaf': [1, 2, 5, 10]}

# %%
rfr=RandomForestRegressor()
#rf_grid = GridSearchCV(estimator = clf, param_grid = param_grid, cv=3,verbose=2,n_jobs=1)
#rf_grid.fit(X_train,y_train)
rf_tunned = RandomizedSearchCV(scoring='neg_mean_squared_error', estimator = rfr, param_distributions = rf_param_grid, n_iter=30, cv=5, verbose=2, n_jobs=1)
rf_tunned.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# [CV] END max_depth=38, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, n_estimators=900; total time=   4.3s
# [CV] END max_depth=38, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, n_estimators=900; total time=   4.0s
# [CV] END max_depth=38, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, n_estimators=900; total time=   3.4s
# [CV] END max_depth=38, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, n_estimators=900; total time=   3.4s
# [CV] END max_depth=38, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, n_estimators=900; total time=   4.0s
# [CV] END max_depth=70, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=1100; total time=  16.5s
# [CV] END max_depth=70, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=1100; total time=  17.2s
# [CV] END max_depth=70, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=1100; total time=  15.5s
# [CV] END max_depth=70, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=1100; total time=  15.1s
# [CV] END max_depth=70, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=1100; total time=  14.6s
# [CV] END max_depth=62, max_features=sqrt, min_samples_leaf=10, min_samples_split=12, n_estimators=1300; total time=   4.6s
# [CV] END max_depth=62, max_features=sqrt, min_samples_leaf=10, min_samples_split=12, n_estimators=1300; total time=   4.4s
# [CV] END max_depth=62, max_features=sqrt, min_samples_leaf=10, min_samples_split=12, n_estimators=1300; total time=   5.7s
# [CV] END max_depth=62, max_features=sqrt, min_samples_leaf=10, min_samples_split=12, n_estimators=1300; total time=   4.5s
# [CV] END max_depth=62, max_features=sqrt, min_samples_leaf=10, min_samples_split=12, n_estimators=1300; total time=   4.5s
# [CV] END max_depth=54, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=1100; total time=   3.7s
# [CV] END max_depth=54, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=1100; total time=   3.8s
# [CV] END max_depth=54, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=1100; total time=   3.8s
# [CV] END max_depth=54, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=1100; total time=   3.8s
# [CV] END max_depth=54, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=1100; total time=   3.7s
# [CV] END max_depth=38, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=900; total time=   5.6s
# [CV] END max_depth=38, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=900; total time=   5.7s
# [CV] END max_depth=38, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=900; total time=   5.7s
# [CV] END max_depth=38, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=900; total time=   5.8s
# [CV] END max_depth=38, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=900; total time=   5.6s
# [CV] END max_depth=46, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=900; total time=   5.2s
# [CV] END max_depth=46, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=900; total time=   5.9s
# [CV] END max_depth=46, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=900; total time=   5.1s
# [CV] END max_depth=46, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=900; total time=   5.0s
# [CV] END max_depth=46, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=900; total time=   5.0s
# [CV] END max_depth=62, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=1100; total time=   7.0s
# [CV] END max_depth=62, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=1100; total time=   7.1s
# [CV] END max_depth=62, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=1100; total time=   7.1s
# [CV] END max_depth=62, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=1100; total time=   7.2s
# [CV] END max_depth=62, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=1100; total time=   7.0s
# [CV] END max_depth=62, max_features=auto, min_samples_leaf=5, min_samples_split=12, n_estimators=1100; total time=  16.2s
# [CV] END max_depth=62, max_features=auto, min_samples_leaf=5, min_samples_split=12, n_estimators=1100; total time=  14.1s
# [CV] END max_depth=62, max_features=auto, min_samples_leaf=5, min_samples_split=12, n_estimators=1100; total time=  14.1s
# [CV] END max_depth=62, max_features=auto, min_samples_leaf=5, min_samples_split=12, n_estimators=1100; total time=  15.2s
# [CV] END max_depth=62, max_features=auto, min_samples_leaf=5, min_samples_split=12, n_estimators=1100; total time=  14.8s
# [CV] END max_depth=62, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, n_estimators=900; total time=   3.3s
# [CV] END max_depth=62, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, n_estimators=900; total time=   3.3s
# [CV] END max_depth=62, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, n_estimators=900; total time=   3.3s
# [CV] END max_depth=62, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, n_estimators=900; total time=   3.3s
# [CV] END max_depth=62, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, n_estimators=900; total time=   3.4s
# [CV] END max_depth=54, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=1200; total time=   5.2s
# [CV] END max_depth=54, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=1200; total time=   5.9s
# [CV] END max_depth=54, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=1200; total time=   7.6s
# [CV] END max_depth=54, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=1200; total time=   6.5s
# [CV] END max_depth=54, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=1200; total time=   6.4s
# [CV] END max_depth=54, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=1300; total time=  22.7s
# [CV] END max_depth=54, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=1300; total time=  27.8s
# [CV] END max_depth=54, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=1300; total time=  11.4s
# [CV] END max_depth=54, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=1300; total time=  10.8s
# [CV] END max_depth=54, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=1300; total time=  10.9s
# [CV] END max_depth=46, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=900; total time=  12.8s
# [CV] END max_depth=46, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=900; total time=  12.7s
# [CV] END max_depth=46, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=900; total time=  13.0s
# [CV] END max_depth=46, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=900; total time=  13.1s
# [CV] END max_depth=46, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=900; total time=  13.1s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=1200; total time=  20.7s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=1200; total time=  19.9s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=1200; total time=  22.0s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=1200; total time=  19.7s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=1200; total time=  19.6s
# [CV] END max_depth=46, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=1200; total time=  26.2s
# [CV] END max_depth=46, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=1200; total time=  24.7s
# [CV] END max_depth=46, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=1200; total time=  23.1s
# [CV] END max_depth=46, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=1200; total time=  26.7s
# [CV] END max_depth=46, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=1200; total time=  19.9s
# [CV] END max_depth=62, max_features=sqrt, min_samples_leaf=10, min_samples_split=3, n_estimators=1100; total time=   4.6s
# [CV] END max_depth=62, max_features=sqrt, min_samples_leaf=10, min_samples_split=3, n_estimators=1100; total time=   6.1s
# [CV] END max_depth=62, max_features=sqrt, min_samples_leaf=10, min_samples_split=3, n_estimators=1100; total time=   7.2s
# [CV] END max_depth=62, max_features=sqrt, min_samples_leaf=10, min_samples_split=3, n_estimators=1100; total time=   9.9s
# [CV] END max_depth=62, max_features=sqrt, min_samples_leaf=10, min_samples_split=3, n_estimators=1100; total time=   7.7s
# [CV] END max_depth=54, max_features=sqrt, min_samples_leaf=10, min_samples_split=17, n_estimators=1100; total time=   7.2s
# [CV] END max_depth=54, max_features=sqrt, min_samples_leaf=10, min_samples_split=17, n_estimators=1100; total time=   5.6s
# [CV] END max_depth=54, max_features=sqrt, min_samples_leaf=10, min_samples_split=17, n_estimators=1100; total time=   4.7s
# [CV] END max_depth=54, max_features=sqrt, min_samples_leaf=10, min_samples_split=17, n_estimators=1100; total time=   4.3s
# [CV] END max_depth=54, max_features=sqrt, min_samples_leaf=10, min_samples_split=17, n_estimators=1100; total time=   4.4s
# [CV] END max_depth=46, max_features=auto, min_samples_leaf=1, min_samples_split=12, n_estimators=1200; total time=  28.6s
# [CV] END max_depth=46, max_features=auto, min_samples_leaf=1, min_samples_split=12, n_estimators=1200; total time=  22.2s
# [CV] END max_depth=46, max_features=auto, min_samples_leaf=1, min_samples_split=12, n_estimators=1200; total time=  17.7s
# [CV] END max_depth=46, max_features=auto, min_samples_leaf=1, min_samples_split=12, n_estimators=1200; total time=  18.3s
# [CV] END max_depth=46, max_features=auto, min_samples_leaf=1, min_samples_split=12, n_estimators=1200; total time=  18.4s
# [CV] END max_depth=62, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=1200; total time=  17.8s
# [CV] END max_depth=62, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=1200; total time=  18.7s
# [CV] END max_depth=62, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=1200; total time=  17.4s
# [CV] END max_depth=62, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=1200; total time=  18.3s
# [CV] END max_depth=62, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=1200; total time=  18.5s
# [CV] END max_depth=70, max_features=sqrt, min_samples_leaf=2, min_samples_split=17, n_estimators=1000; total time=   4.2s
# [CV] END max_depth=70, max_features=sqrt, min_samples_leaf=2, min_samples_split=17, n_estimators=1000; total time=   4.0s
# [CV] END max_depth=70, max_features=sqrt, min_samples_leaf=2, min_samples_split=17, n_estimators=1000; total time=   4.0s
# [CV] END max_depth=70, max_features=sqrt, min_samples_leaf=2, min_samples_split=17, n_estimators=1000; total time=   4.1s
# [CV] END max_depth=70, max_features=sqrt, min_samples_leaf=2, min_samples_split=17, n_estimators=1000; total time=   4.1s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, n_estimators=1400; total time=   4.9s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, n_estimators=1400; total time=   5.0s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, n_estimators=1400; total time=   4.9s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, n_estimators=1400; total time=   4.9s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, n_estimators=1400; total time=   4.9s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=5, min_samples_split=3, n_estimators=1200; total time=  16.5s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=5, min_samples_split=3, n_estimators=1200; total time=  16.4s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=5, min_samples_split=3, n_estimators=1200; total time=  21.7s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=5, min_samples_split=3, n_estimators=1200; total time=  24.5s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=5, min_samples_split=3, n_estimators=1200; total time=  30.1s
# [CV] END max_depth=54, max_features=auto, min_samples_leaf=2, min_samples_split=15, n_estimators=1200; total time=  28.5s
# [CV] END max_depth=54, max_features=auto, min_samples_leaf=2, min_samples_split=15, n_estimators=1200; total time=  23.2s
# [CV] END max_depth=54, max_features=auto, min_samples_leaf=2, min_samples_split=15, n_estimators=1200; total time=  31.2s
# [CV] END max_depth=54, max_features=auto, min_samples_leaf=2, min_samples_split=15, n_estimators=1200; total time=  24.6s
# [CV] END max_depth=54, max_features=auto, min_samples_leaf=2, min_samples_split=15, n_estimators=1200; total time=  19.7s
# [CV] END max_depth=54, max_features=auto, min_samples_leaf=2, min_samples_split=15, n_estimators=1300; total time=  20.5s
# [CV] END max_depth=54, max_features=auto, min_samples_leaf=2, min_samples_split=15, n_estimators=1300; total time=  20.7s
# [CV] END max_depth=54, max_features=auto, min_samples_leaf=2, min_samples_split=15, n_estimators=1300; total time=  20.1s
# [CV] END max_depth=54, max_features=auto, min_samples_leaf=2, min_samples_split=15, n_estimators=1300; total time=  28.8s
# [CV] END max_depth=54, max_features=auto, min_samples_leaf=2, min_samples_split=15, n_estimators=1300; total time=  22.0s
# [CV] END max_depth=54, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=1400; total time=   6.5s
# [CV] END max_depth=54, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=1400; total time=   6.0s
# [CV] END max_depth=54, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=1400; total time=   9.6s
# [CV] END max_depth=54, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=1400; total time=   7.6s
# [CV] END max_depth=54, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=1400; total time=   8.2s
# [CV] END max_depth=62, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=900; total time=   9.3s
# [CV] END max_depth=62, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=900; total time=   9.5s
# [CV] END max_depth=62, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=900; total time=   6.3s
# [CV] END max_depth=62, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=900; total time=   8.7s
# [CV] END max_depth=62, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=900; total time=  10.7s
# [CV] END max_depth=62, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1400; total time=  13.0s
# [CV] END max_depth=62, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1400; total time=  10.5s
# [CV] END max_depth=62, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1400; total time=  11.0s
# [CV] END max_depth=62, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1400; total time=  11.3s
# [CV] END max_depth=62, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1400; total time=  15.0s
# [CV] END max_depth=62, max_features=sqrt, min_samples_leaf=2, min_samples_split=12, n_estimators=1300; total time=   7.6s
# [CV] END max_depth=62, max_features=sqrt, min_samples_leaf=2, min_samples_split=12, n_estimators=1300; total time=   7.4s
# [CV] END max_depth=62, max_features=sqrt, min_samples_leaf=2, min_samples_split=12, n_estimators=1300; total time=   8.2s
# [CV] END max_depth=62, max_features=sqrt, min_samples_leaf=2, min_samples_split=12, n_estimators=1300; total time=  10.5s
# [CV] END max_depth=62, max_features=sqrt, min_samples_leaf=2, min_samples_split=12, n_estimators=1300; total time=  10.3s
# [CV] END max_depth=38, max_features=sqrt, min_samples_leaf=5, min_samples_split=17, n_estimators=1200; total time=   9.2s
# [CV] END max_depth=38, max_features=sqrt, min_samples_leaf=5, min_samples_split=17, n_estimators=1200; total time=   7.0s
# [CV] END max_depth=38, max_features=sqrt, min_samples_leaf=5, min_samples_split=17, n_estimators=1200; total time=   9.8s
# [CV] END max_depth=38, max_features=sqrt, min_samples_leaf=5, min_samples_split=17, n_estimators=1200; total time=   7.0s
# [CV] END max_depth=38, max_features=sqrt, min_samples_leaf=5, min_samples_split=17, n_estimators=1200; total time=   5.6s
# [CV] END max_depth=54, max_features=auto, min_samples_leaf=2, min_samples_split=17, n_estimators=1000; total time=  18.8s
# [CV] END max_depth=54, max_features=auto, min_samples_leaf=2, min_samples_split=17, n_estimators=1000; total time=  16.9s
# [CV] END max_depth=54, max_features=auto, min_samples_leaf=2, min_samples_split=17, n_estimators=1000; total time=  18.3s
# [CV] END max_depth=54, max_features=auto, min_samples_leaf=2, min_samples_split=17, n_estimators=1000; total time=  16.8s
# [CV] END max_depth=54, max_features=auto, min_samples_leaf=2, min_samples_split=17, n_estimators=1000; total time=  20.1s
# [CV] END max_depth=62, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=1400; total time=   6.4s
# [CV] END max_depth=62, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=1400; total time=   7.0s
# [CV] END max_depth=62, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=1400; total time=   7.3s
# [CV] END max_depth=62, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=1400; total time=   6.5s
# [CV] END max_depth=62, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=1400; total time=   9.6s
# RandomizedSearchCV(cv=5, estimator=RandomForestRegressor(), n_iter=30, n_jobs=1,
#                    param_distributions={'max_depth': [30, 38, 46, 54, 62, 70],
#                                         'max_features': ['auto', 'sqrt'],
#                                         'min_samples_leaf': [1, 2, 5, 10],
#                                         'min_samples_split': [3, 5, 10, 12, 15,
#                                                               17, 20],
#                                         'n_estimators': [900, 1000, 1100, 1200,
#                                                          1300, 1400]},
#                    scoring='neg_mean_squared_error', verbose=2)

# %%
rf_tunned.best_params_
# Out:
# {'n_estimators': 1200,
#  'min_samples_split': 10,
#  'min_samples_leaf': 1,
#  'max_features': 'auto',
#  'max_depth': 46}

# %%
y_pred = rf_tunned.predict(X_test)
rmse = float(format(np.sqrt(mean_squared_error(y_test, y_pred)), '.3f'))
print("RMSE: ", rmse)
mse = float(format(mean_squared_error(y_test, y_pred), '.3f'))
print("MSE: ", mse)
r2 = float(format(r2_score(y_test, y_pred), '.3f'))
print("R2: ", r2)
models.append('Random Forest (t)')
rmse_lst.append(rmse)
mse_lst.append(mse)
r2_lst.append(r2)
# Out:
# RMSE:  1426.809
# MSE:  2035783.794
# R2:  0.899

# %%
rf_tunned_importance = rf_tunned.best_estimator_.feature_importances_
rf_tunned_names = rf_tunned.best_estimator_.feature_names_in_

rf_tunned_import_df = pd.DataFrame({"feature_names" : rf_tunned_names, 
                               "rf_tunned_importances" : rf_tunned_importance.round(3)})
rf_tunned_import_df['rf_tunned_impt_rank'] = rf_tunned_import_df['rf_tunned_importances'].rank(method='dense', ascending=False)

# %%
rf_tunned_import_df.sort_values('rf_tunned_importances', ascending=False).head(7)
# Out:
#                                   feature_names  rf_tunned_importances  \
# 4                                  Duration_min                  0.466
# 33  Additional_Info_In-flight meal not included                  0.080
# 2                                       Dep_Day                  0.079
# 13                 Airline_Jet Airways Business                  0.075
# 12                          Airline_Jet Airways                  0.060
# 3                                     Dep_Month                  0.048
# 5                                        Route2                  0.028
#
#     rf_tunned_impt_rank
# 4                   1.0
# 33                  2.0
# 2                   3.0
# 13                  4.0
# 12                  5.0
# 3                   6.0
# 5                   7.0

# %%
#XG Boost
params = {
 "n_estimators": [int(x) for x in np.linspace(start=400,stop=700,num=7)], # Number of trees in random forest
 "learning_rate" : [0.01,0.02,0.04, 0.05,0.06,0.07],
 "max_depth" : [ 3, 4, 5, 6, 8, 10],
 "min_child_weight" : [2, 3, 4, 5],
 "gamma": [ 0.0, 0.1, 0.2 , 0.3, 0.4 ],
 "colsample_bytree" : [ 0.3, 0.4, 0.5 ,0.6, 0.7 ]
}

# %%
###### xgb = XGBRegressor()
xgb_model_tuned = RandomizedSearchCV(estimator = xgb, param_distributions = params, scoring='neg_mean_squared_error', n_iter = 30, cv = 5, verbose=2, random_state=42, n_jobs = 1)
xgb_model_tuned.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# [CV] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.04, max_depth=8, min_child_weight=5, n_estimators=450; total time=   5.6s
# [CV] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.04, max_depth=8, min_child_weight=5, n_estimators=450; total time=   5.8s
# [CV] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.04, max_depth=8, min_child_weight=5, n_estimators=450; total time=   5.5s
# [CV] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.04, max_depth=8, min_child_weight=5, n_estimators=450; total time=   6.4s
# [CV] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.04, max_depth=8, min_child_weight=5, n_estimators=450; total time=   5.5s
# [CV] END colsample_bytree=0.6, gamma=0.0, learning_rate=0.06, max_depth=3, min_child_weight=2, n_estimators=550; total time=   2.6s
# [CV] END colsample_bytree=0.6, gamma=0.0, learning_rate=0.06, max_depth=3, min_child_weight=2, n_estimators=550; total time=   2.2s
# [CV] END colsample_bytree=0.6, gamma=0.0, learning_rate=0.06, max_depth=3, min_child_weight=2, n_estimators=550; total time=   2.0s
# [CV] END colsample_bytree=0.6, gamma=0.0, learning_rate=0.06, max_depth=3, min_child_weight=2, n_estimators=550; total time=   2.7s
# [CV] END colsample_bytree=0.6, gamma=0.0, learning_rate=0.06, max_depth=3, min_child_weight=2, n_estimators=550; total time=   2.2s
# [CV] END colsample_bytree=0.3, gamma=0.0, learning_rate=0.07, max_depth=3, min_child_weight=4, n_estimators=700; total time=   2.1s
# [CV] END colsample_bytree=0.3, gamma=0.0, learning_rate=0.07, max_depth=3, min_child_weight=4, n_estimators=700; total time=   2.2s
# [CV] END colsample_bytree=0.3, gamma=0.0, learning_rate=0.07, max_depth=3, min_child_weight=4, n_estimators=700; total time=   2.5s
# [CV] END colsample_bytree=0.3, gamma=0.0, learning_rate=0.07, max_depth=3, min_child_weight=4, n_estimators=700; total time=   2.3s
# [CV] END colsample_bytree=0.3, gamma=0.0, learning_rate=0.07, max_depth=3, min_child_weight=4, n_estimators=700; total time=   2.5s
# [CV] END colsample_bytree=0.4, gamma=0.0, learning_rate=0.04, max_depth=3, min_child_weight=4, n_estimators=400; total time=   1.6s
# [CV] END colsample_bytree=0.4, gamma=0.0, learning_rate=0.04, max_depth=3, min_child_weight=4, n_estimators=400; total time=   1.5s
# [CV] END colsample_bytree=0.4, gamma=0.0, learning_rate=0.04, max_depth=3, min_child_weight=4, n_estimators=400; total time=   1.4s
# [CV] END colsample_bytree=0.4, gamma=0.0, learning_rate=0.04, max_depth=3, min_child_weight=4, n_estimators=400; total time=   1.6s
# [CV] END colsample_bytree=0.4, gamma=0.0, learning_rate=0.04, max_depth=3, min_child_weight=4, n_estimators=400; total time=   1.4s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.04, max_depth=5, min_child_weight=4, n_estimators=450; total time=   2.9s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.04, max_depth=5, min_child_weight=4, n_estimators=450; total time=   2.9s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.04, max_depth=5, min_child_weight=4, n_estimators=450; total time=   2.8s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.04, max_depth=5, min_child_weight=4, n_estimators=450; total time=   3.1s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.04, max_depth=5, min_child_weight=4, n_estimators=450; total time=   2.7s
# [CV] END colsample_bytree=0.5, gamma=0.1, learning_rate=0.07, max_depth=4, min_child_weight=3, n_estimators=450; total time=   2.2s
# [CV] END colsample_bytree=0.5, gamma=0.1, learning_rate=0.07, max_depth=4, min_child_weight=3, n_estimators=450; total time=   2.1s
# [CV] END colsample_bytree=0.5, gamma=0.1, learning_rate=0.07, max_depth=4, min_child_weight=3, n_estimators=450; total time=   2.8s
# [CV] END colsample_bytree=0.5, gamma=0.1, learning_rate=0.07, max_depth=4, min_child_weight=3, n_estimators=450; total time=   2.4s
# [CV] END colsample_bytree=0.5, gamma=0.1, learning_rate=0.07, max_depth=4, min_child_weight=3, n_estimators=450; total time=   2.4s
# [CV] END colsample_bytree=0.5, gamma=0.1, learning_rate=0.02, max_depth=4, min_child_weight=2, n_estimators=400; total time=   2.2s
# [CV] END colsample_bytree=0.5, gamma=0.1, learning_rate=0.02, max_depth=4, min_child_weight=2, n_estimators=400; total time=   1.9s
# [CV] END colsample_bytree=0.5, gamma=0.1, learning_rate=0.02, max_depth=4, min_child_weight=2, n_estimators=400; total time=   2.1s
# [CV] END colsample_bytree=0.5, gamma=0.1, learning_rate=0.02, max_depth=4, min_child_weight=2, n_estimators=400; total time=   1.9s
# [CV] END colsample_bytree=0.5, gamma=0.1, learning_rate=0.02, max_depth=4, min_child_weight=2, n_estimators=400; total time=   2.0s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.07, max_depth=6, min_child_weight=5, n_estimators=650; total time=   4.7s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.07, max_depth=6, min_child_weight=5, n_estimators=650; total time=   5.0s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.07, max_depth=6, min_child_weight=5, n_estimators=650; total time=   5.0s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.07, max_depth=6, min_child_weight=5, n_estimators=650; total time=   5.7s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.07, max_depth=6, min_child_weight=5, n_estimators=650; total time=   5.8s
# [CV] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.02, max_depth=4, min_child_weight=5, n_estimators=400; total time=   2.0s
# [CV] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.02, max_depth=4, min_child_weight=5, n_estimators=400; total time=   1.8s
# [CV] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.02, max_depth=4, min_child_weight=5, n_estimators=400; total time=   1.9s
# [CV] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.02, max_depth=4, min_child_weight=5, n_estimators=400; total time=   1.7s
# [CV] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.02, max_depth=4, min_child_weight=5, n_estimators=400; total time=   1.7s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.06, max_depth=4, min_child_weight=5, n_estimators=450; total time=   2.3s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.06, max_depth=4, min_child_weight=5, n_estimators=450; total time=   2.3s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.06, max_depth=4, min_child_weight=5, n_estimators=450; total time=   2.3s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.06, max_depth=4, min_child_weight=5, n_estimators=450; total time=   2.3s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.06, max_depth=4, min_child_weight=5, n_estimators=450; total time=   2.2s
# [CV] END colsample_bytree=0.3, gamma=0.4, learning_rate=0.04, max_depth=5, min_child_weight=2, n_estimators=500; total time=   2.4s
# [CV] END colsample_bytree=0.3, gamma=0.4, learning_rate=0.04, max_depth=5, min_child_weight=2, n_estimators=500; total time=   2.8s
# [CV] END colsample_bytree=0.3, gamma=0.4, learning_rate=0.04, max_depth=5, min_child_weight=2, n_estimators=500; total time=   2.9s
# [CV] END colsample_bytree=0.3, gamma=0.4, learning_rate=0.04, max_depth=5, min_child_weight=2, n_estimators=500; total time=   2.6s
# [CV] END colsample_bytree=0.3, gamma=0.4, learning_rate=0.04, max_depth=5, min_child_weight=2, n_estimators=500; total time=   2.6s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.06, max_depth=8, min_child_weight=3, n_estimators=550; total time=   7.1s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.06, max_depth=8, min_child_weight=3, n_estimators=550; total time=   5.5s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.06, max_depth=8, min_child_weight=3, n_estimators=550; total time=   5.0s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.06, max_depth=8, min_child_weight=3, n_estimators=550; total time=   7.5s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.06, max_depth=8, min_child_weight=3, n_estimators=550; total time=   8.0s
# [CV] END colsample_bytree=0.5, gamma=0.4, learning_rate=0.02, max_depth=10, min_child_weight=2, n_estimators=550; total time=   6.1s
# [CV] END colsample_bytree=0.5, gamma=0.4, learning_rate=0.02, max_depth=10, min_child_weight=2, n_estimators=550; total time=   6.5s
# [CV] END colsample_bytree=0.5, gamma=0.4, learning_rate=0.02, max_depth=10, min_child_weight=2, n_estimators=550; total time=   6.1s
# [CV] END colsample_bytree=0.5, gamma=0.4, learning_rate=0.02, max_depth=10, min_child_weight=2, n_estimators=550; total time=   5.4s
# [CV] END colsample_bytree=0.5, gamma=0.4, learning_rate=0.02, max_depth=10, min_child_weight=2, n_estimators=550; total time=   5.8s
# [CV] END colsample_bytree=0.5, gamma=0.1, learning_rate=0.02, max_depth=6, min_child_weight=5, n_estimators=500; total time=   2.8s
# [CV] END colsample_bytree=0.5, gamma=0.1, learning_rate=0.02, max_depth=6, min_child_weight=5, n_estimators=500; total time=   3.2s
# [CV] END colsample_bytree=0.5, gamma=0.1, learning_rate=0.02, max_depth=6, min_child_weight=5, n_estimators=500; total time=   2.9s
# [CV] END colsample_bytree=0.5, gamma=0.1, learning_rate=0.02, max_depth=6, min_child_weight=5, n_estimators=500; total time=   3.0s
# [CV] END colsample_bytree=0.5, gamma=0.1, learning_rate=0.02, max_depth=6, min_child_weight=5, n_estimators=500; total time=   2.7s
# [CV] END colsample_bytree=0.6, gamma=0.0, learning_rate=0.07, max_depth=5, min_child_weight=3, n_estimators=400; total time=   2.1s
# [CV] END colsample_bytree=0.6, gamma=0.0, learning_rate=0.07, max_depth=5, min_child_weight=3, n_estimators=400; total time=   2.2s
# [CV] END colsample_bytree=0.6, gamma=0.0, learning_rate=0.07, max_depth=5, min_child_weight=3, n_estimators=400; total time=   3.2s
# [CV] END colsample_bytree=0.6, gamma=0.0, learning_rate=0.07, max_depth=5, min_child_weight=3, n_estimators=400; total time=   4.2s
# [CV] END colsample_bytree=0.6, gamma=0.0, learning_rate=0.07, max_depth=5, min_child_weight=3, n_estimators=400; total time=   3.4s
# [CV] END colsample_bytree=0.4, gamma=0.3, learning_rate=0.02, max_depth=6, min_child_weight=2, n_estimators=700; total time=   4.6s
# [CV] END colsample_bytree=0.4, gamma=0.3, learning_rate=0.02, max_depth=6, min_child_weight=2, n_estimators=700; total time=   4.1s
# [CV] END colsample_bytree=0.4, gamma=0.3, learning_rate=0.02, max_depth=6, min_child_weight=2, n_estimators=700; total time=   4.3s
# [CV] END colsample_bytree=0.4, gamma=0.3, learning_rate=0.02, max_depth=6, min_child_weight=2, n_estimators=700; total time=   4.4s
# [CV] END colsample_bytree=0.4, gamma=0.3, learning_rate=0.02, max_depth=6, min_child_weight=2, n_estimators=700; total time=   4.2s
# [CV] END colsample_bytree=0.3, gamma=0.1, learning_rate=0.06, max_depth=3, min_child_weight=2, n_estimators=650; total time=   2.3s
# [CV] END colsample_bytree=0.3, gamma=0.1, learning_rate=0.06, max_depth=3, min_child_weight=2, n_estimators=650; total time=   2.6s
# [CV] END colsample_bytree=0.3, gamma=0.1, learning_rate=0.06, max_depth=3, min_child_weight=2, n_estimators=650; total time=   2.1s
# [CV] END colsample_bytree=0.3, gamma=0.1, learning_rate=0.06, max_depth=3, min_child_weight=2, n_estimators=650; total time=   2.2s
# [CV] END colsample_bytree=0.3, gamma=0.1, learning_rate=0.06, max_depth=3, min_child_weight=2, n_estimators=650; total time=   2.1s
# [CV] END colsample_bytree=0.3, gamma=0.0, learning_rate=0.06, max_depth=6, min_child_weight=3, n_estimators=700; total time=   3.7s
# [CV] END colsample_bytree=0.3, gamma=0.0, learning_rate=0.06, max_depth=6, min_child_weight=3, n_estimators=700; total time=   3.9s
# [CV] END colsample_bytree=0.3, gamma=0.0, learning_rate=0.06, max_depth=6, min_child_weight=3, n_estimators=700; total time=   3.9s
# [CV] END colsample_bytree=0.3, gamma=0.0, learning_rate=0.06, max_depth=6, min_child_weight=3, n_estimators=700; total time=   4.5s
# [CV] END colsample_bytree=0.3, gamma=0.0, learning_rate=0.06, max_depth=6, min_child_weight=3, n_estimators=700; total time=   3.9s
# [CV] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.01, max_depth=10, min_child_weight=3, n_estimators=500; total time=  12.2s
# [CV] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.01, max_depth=10, min_child_weight=3, n_estimators=500; total time=  10.5s
# [CV] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.01, max_depth=10, min_child_weight=3, n_estimators=500; total time=   7.9s
# [CV] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.01, max_depth=10, min_child_weight=3, n_estimators=500; total time=   8.0s
# [CV] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.01, max_depth=10, min_child_weight=3, n_estimators=500; total time=   7.8s
# [CV] END colsample_bytree=0.3, gamma=0.2, learning_rate=0.04, max_depth=5, min_child_weight=5, n_estimators=600; total time=   3.2s
# [CV] END colsample_bytree=0.3, gamma=0.2, learning_rate=0.04, max_depth=5, min_child_weight=5, n_estimators=600; total time=   3.0s
# [CV] END colsample_bytree=0.3, gamma=0.2, learning_rate=0.04, max_depth=5, min_child_weight=5, n_estimators=600; total time=   3.0s
# [CV] END colsample_bytree=0.3, gamma=0.2, learning_rate=0.04, max_depth=5, min_child_weight=5, n_estimators=600; total time=   3.1s
# [CV] END colsample_bytree=0.3, gamma=0.2, learning_rate=0.04, max_depth=5, min_child_weight=5, n_estimators=600; total time=   3.9s
# [CV] END colsample_bytree=0.4, gamma=0.0, learning_rate=0.02, max_depth=6, min_child_weight=4, n_estimators=650; total time=   4.6s
# [CV] END colsample_bytree=0.4, gamma=0.0, learning_rate=0.02, max_depth=6, min_child_weight=4, n_estimators=650; total time=   3.9s
# [CV] END colsample_bytree=0.4, gamma=0.0, learning_rate=0.02, max_depth=6, min_child_weight=4, n_estimators=650; total time=   4.1s
# [CV] END colsample_bytree=0.4, gamma=0.0, learning_rate=0.02, max_depth=6, min_child_weight=4, n_estimators=650; total time=   4.4s
# [CV] END colsample_bytree=0.4, gamma=0.0, learning_rate=0.02, max_depth=6, min_child_weight=4, n_estimators=650; total time=   5.1s
# [CV] END colsample_bytree=0.4, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=3, n_estimators=600; total time=   2.6s
# [CV] END colsample_bytree=0.4, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=3, n_estimators=600; total time=   2.9s
# [CV] END colsample_bytree=0.4, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=3, n_estimators=600; total time=   2.5s
# [CV] END colsample_bytree=0.4, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=3, n_estimators=600; total time=   2.1s
# [CV] END colsample_bytree=0.4, gamma=0.0, learning_rate=0.01, max_depth=3, min_child_weight=3, n_estimators=600; total time=   2.1s
# [CV] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.04, max_depth=4, min_child_weight=3, n_estimators=450; total time=   1.9s
# [CV] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.04, max_depth=4, min_child_weight=3, n_estimators=450; total time=   2.0s
# [CV] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.04, max_depth=4, min_child_weight=3, n_estimators=450; total time=   1.8s
# [CV] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.04, max_depth=4, min_child_weight=3, n_estimators=450; total time=   1.9s
# [CV] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.04, max_depth=4, min_child_weight=3, n_estimators=450; total time=   1.9s
# [CV] END colsample_bytree=0.6, gamma=0.2, learning_rate=0.04, max_depth=6, min_child_weight=3, n_estimators=650; total time=   4.2s
# [CV] END colsample_bytree=0.6, gamma=0.2, learning_rate=0.04, max_depth=6, min_child_weight=3, n_estimators=650; total time=   4.3s
# [CV] END colsample_bytree=0.6, gamma=0.2, learning_rate=0.04, max_depth=6, min_child_weight=3, n_estimators=650; total time=   4.9s
# [CV] END colsample_bytree=0.6, gamma=0.2, learning_rate=0.04, max_depth=6, min_child_weight=3, n_estimators=650; total time=   5.0s
# [CV] END colsample_bytree=0.6, gamma=0.2, learning_rate=0.04, max_depth=6, min_child_weight=3, n_estimators=650; total time=   4.6s
# [CV] END colsample_bytree=0.7, gamma=0.0, learning_rate=0.06, max_depth=6, min_child_weight=5, n_estimators=500; total time=   3.6s
# [CV] END colsample_bytree=0.7, gamma=0.0, learning_rate=0.06, max_depth=6, min_child_weight=5, n_estimators=500; total time=   3.7s
# [CV] END colsample_bytree=0.7, gamma=0.0, learning_rate=0.06, max_depth=6, min_child_weight=5, n_estimators=500; total time=   3.6s
# [CV] END colsample_bytree=0.7, gamma=0.0, learning_rate=0.06, max_depth=6, min_child_weight=5, n_estimators=500; total time=   3.5s
# [CV] END colsample_bytree=0.7, gamma=0.0, learning_rate=0.06, max_depth=6, min_child_weight=5, n_estimators=500; total time=   3.6s
# [CV] END colsample_bytree=0.6, gamma=0.4, learning_rate=0.05, max_depth=8, min_child_weight=2, n_estimators=450; total time=   4.2s
# [CV] END colsample_bytree=0.6, gamma=0.4, learning_rate=0.05, max_depth=8, min_child_weight=2, n_estimators=450; total time=   4.2s
# [CV] END colsample_bytree=0.6, gamma=0.4, learning_rate=0.05, max_depth=8, min_child_weight=2, n_estimators=450; total time=   5.5s
# [CV] END colsample_bytree=0.6, gamma=0.4, learning_rate=0.05, max_depth=8, min_child_weight=2, n_estimators=450; total time=   4.1s
# [CV] END colsample_bytree=0.6, gamma=0.4, learning_rate=0.05, max_depth=8, min_child_weight=2, n_estimators=450; total time=   4.1s
# [CV] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.04, max_depth=3, min_child_weight=3, n_estimators=650; total time=   2.7s
# [CV] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.04, max_depth=3, min_child_weight=3, n_estimators=650; total time=   2.4s
# [CV] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.04, max_depth=3, min_child_weight=3, n_estimators=650; total time=   2.3s
# [CV] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.04, max_depth=3, min_child_weight=3, n_estimators=650; total time=   3.2s
# [CV] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.04, max_depth=3, min_child_weight=3, n_estimators=650; total time=   3.2s
# [CV] END colsample_bytree=0.4, gamma=0.3, learning_rate=0.05, max_depth=6, min_child_weight=4, n_estimators=400; total time=   2.7s
# [CV] END colsample_bytree=0.4, gamma=0.3, learning_rate=0.05, max_depth=6, min_child_weight=4, n_estimators=400; total time=   3.0s
# [CV] END colsample_bytree=0.4, gamma=0.3, learning_rate=0.05, max_depth=6, min_child_weight=4, n_estimators=400; total time=   2.6s
# [CV] END colsample_bytree=0.4, gamma=0.3, learning_rate=0.05, max_depth=6, min_child_weight=4, n_estimators=400; total time=   2.7s
# [CV] END colsample_bytree=0.4, gamma=0.3, learning_rate=0.05, max_depth=6, min_child_weight=4, n_estimators=400; total time=   2.8s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.06, max_depth=8, min_child_weight=4, n_estimators=400; total time=   5.7s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.06, max_depth=8, min_child_weight=4, n_estimators=400; total time=   6.3s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.06, max_depth=8, min_child_weight=4, n_estimators=400; total time=   4.6s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.06, max_depth=8, min_child_weight=4, n_estimators=400; total time=   5.2s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.06, max_depth=8, min_child_weight=4, n_estimators=400; total time=   4.2s
# [CV] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.01, max_depth=4, min_child_weight=3, n_estimators=700; total time=   4.0s
# [CV] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.01, max_depth=4, min_child_weight=3, n_estimators=700; total time=   3.6s
# [CV] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.01, max_depth=4, min_child_weight=3, n_estimators=700; total time=   3.6s
# [CV] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.01, max_depth=4, min_child_weight=3, n_estimators=700; total time=   3.6s
# [CV] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.01, max_depth=4, min_child_weight=3, n_estimators=700; total time=   3.9s
# RandomizedSearchCV(cv=5,
#                    estimator=XGBRegressor(base_score=None, booster=None,
#                                           callbacks=None,
#                                           colsample_bylevel=None,
#                                           colsample_bynode=None,
#                                           colsample_bytree=None,
#                                           early_stopping_rounds=None,
#                                           enable_categorical=False,
#                                           eval_metric=None, feature_types=None,
#                                           gamma=None, gpu_id=None,
#                                           grow_policy=None,
#                                           importance_type=None,
#                                           interaction_constraints=None,
#                                           learning_rate=...
#                                           predictor=None, random_state=None, ...),
#                    n_iter=30, n_jobs=1,
#                    param_distributions={'colsample_bytree': [0.3, 0.4, 0.5, 0.6,
#                                                              0.7],
#                                         'gamma': [0.0, 0.1, 0.2, 0.3, 0.4],
#                                         'learning_rate': [0.01, 0.02, 0.04,
#                                                           0.05, 0.06, 0.07],
#                                         'max_depth': [3, 4, 5, 6, 8, 10],
#                                         'min_child_weight': [2, 3, 4, 5],
#                                         'n_estimators': [400, 450, 500, 550,
#                                                          600, 650, 700]},
#                    random_state=42, scoring='neg_mean_squared_error',
#                    verbose=2)

# %%
xgb_model_tuned.best_params_
# Out:
# {'n_estimators': 550,
#  'min_child_weight': 3,
#  'max_depth': 8,
#  'learning_rate': 0.06,
#  'gamma': 0.1,
#  'colsample_bytree': 0.7}

# %%
y_pred = xgb_model_tuned.predict(X_test)
rmse = float(format(np.sqrt(mean_squared_error(y_test, y_pred)), '.3f'))
print("RMSE: ", rmse)
mse = float(format(mean_squared_error(y_test, y_pred), '.3f'))
print("MSE: ", mse)
r2 = float(format(r2_score(y_test, y_pred), '.3f'))
print("R2: ", r2)
models.append('XGBoost (t)')
rmse_lst.append(rmse)
mse_lst.append(mse)
r2_lst.append(r2)
# Out:
# RMSE:  1348.061
# MSE:  1817269.166
# R2:  0.909

# %%
xgb_tunned_importance = xgb_model_tuned.best_estimator_.feature_importances_
xgb_tunned_names = xgb_model_tuned.best_estimator_.feature_names_in_

xgb_tunned_import_df = pd.DataFrame({"feature_names" : xgb_tunned_names, 
                               "xgb_tunned_importances" : xgb_tunned_importance.round(3)})
xgb_tunned_import_df['xgb_tunned_impt_rank'] = xgb_tunned_import_df['xgb_tunned_importances'].rank(method='dense', ascending=False)

# %%
xgb_tunned_import_df.sort_values('xgb_tunned_importances', ascending=False).head(7)
# Out:
#                                   feature_names  xgb_tunned_importances  \
# 13                 Airline_Jet Airways Business                   0.268
# 12                          Airline_Jet Airways                   0.109
# 0                                   Total_Stops                   0.082
# 33  Additional_Info_In-flight meal not included                   0.082
# 4                                  Duration_min                   0.049
# 36                      Additional_Info_No info                   0.039
# 11                               Airline_IndiGo                   0.038
#
#     xgb_tunned_impt_rank
# 13                   1.0
# 12                   2.0
# 0                    3.0
# 33                   3.0
# 4                    4.0
# 36                   5.0
# 11                   6.0

# %%
#Gradient Boosting
n_estimators = [int(x) for x in np.linspace(start=50,stop=200,num=10)] # Number of trees in random forest
max_features = ['auto', 'sqrt'] # Number of features to consider at every split
max_depth = [10,12,13,14,15,17] # Max number of levels in tree
min_samples_split = [10,15,18,20,22,24] # Min number of samples required to split a node
min_samples_leaf = [2,3,4,5,7,10] # Min number of samples requred at each leaft node

gbr_param_grid = {
    
    'n_estimators': n_estimators,
    'max_features': max_features, 
    'max_depth': max_depth, 
    'min_samples_split': min_samples_split,
    'min_samples_leaf': min_samples_leaf,
}

# %%
gbr = GradientBoostingRegressor(learning_rate=0.1, loss='squared_error')
gbr_tunned = RandomizedSearchCV(estimator = gbr, param_distributions = gbr_param_grid, n_iter=30, cv=5, verbose=2, n_jobs=1)
gbr_tunned.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=4, min_samples_split=22, n_estimators=116; total time=   1.1s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=4, min_samples_split=22, n_estimators=116; total time=   0.7s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=4, min_samples_split=22, n_estimators=116; total time=   0.7s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=4, min_samples_split=22, n_estimators=116; total time=   0.7s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=4, min_samples_split=22, n_estimators=116; total time=   0.7s
# [CV] END max_depth=12, max_features=auto, min_samples_leaf=10, min_samples_split=20, n_estimators=100; total time=   2.6s
# [CV] END max_depth=12, max_features=auto, min_samples_leaf=10, min_samples_split=20, n_estimators=100; total time=   2.6s
# [CV] END max_depth=12, max_features=auto, min_samples_leaf=10, min_samples_split=20, n_estimators=100; total time=   2.7s
# [CV] END max_depth=12, max_features=auto, min_samples_leaf=10, min_samples_split=20, n_estimators=100; total time=   2.7s
# [CV] END max_depth=12, max_features=auto, min_samples_leaf=10, min_samples_split=20, n_estimators=100; total time=   3.0s
# [CV] END max_depth=17, max_features=sqrt, min_samples_leaf=10, min_samples_split=18, n_estimators=66; total time=   0.3s
# [CV] END max_depth=17, max_features=sqrt, min_samples_leaf=10, min_samples_split=18, n_estimators=66; total time=   0.3s
# [CV] END max_depth=17, max_features=sqrt, min_samples_leaf=10, min_samples_split=18, n_estimators=66; total time=   0.3s
# [CV] END max_depth=17, max_features=sqrt, min_samples_leaf=10, min_samples_split=18, n_estimators=66; total time=   0.3s
# [CV] END max_depth=17, max_features=sqrt, min_samples_leaf=10, min_samples_split=18, n_estimators=66; total time=   0.3s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=20, n_estimators=100; total time=   2.4s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=20, n_estimators=100; total time=   2.4s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=20, n_estimators=100; total time=   2.4s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=20, n_estimators=100; total time=   2.3s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=20, n_estimators=100; total time=   2.4s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=24, n_estimators=183; total time=   6.0s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=24, n_estimators=183; total time=   5.8s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=24, n_estimators=183; total time=   6.1s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=24, n_estimators=183; total time=   6.0s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=24, n_estimators=183; total time=   6.2s
# [CV] END max_depth=14, max_features=sqrt, min_samples_leaf=10, min_samples_split=22, n_estimators=166; total time=   0.9s
# [CV] END max_depth=14, max_features=sqrt, min_samples_leaf=10, min_samples_split=22, n_estimators=166; total time=   0.9s
# [CV] END max_depth=14, max_features=sqrt, min_samples_leaf=10, min_samples_split=22, n_estimators=166; total time=   0.9s
# [CV] END max_depth=14, max_features=sqrt, min_samples_leaf=10, min_samples_split=22, n_estimators=166; total time=   0.9s
# [CV] END max_depth=14, max_features=sqrt, min_samples_leaf=10, min_samples_split=22, n_estimators=166; total time=   0.9s
# [CV] END max_depth=17, max_features=auto, min_samples_leaf=4, min_samples_split=15, n_estimators=83; total time=   2.7s
# [CV] END max_depth=17, max_features=auto, min_samples_leaf=4, min_samples_split=15, n_estimators=83; total time=   2.6s
# [CV] END max_depth=17, max_features=auto, min_samples_leaf=4, min_samples_split=15, n_estimators=83; total time=   2.7s
# [CV] END max_depth=17, max_features=auto, min_samples_leaf=4, min_samples_split=15, n_estimators=83; total time=   2.8s
# [CV] END max_depth=17, max_features=auto, min_samples_leaf=4, min_samples_split=15, n_estimators=83; total time=   2.7s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=20, n_estimators=183; total time=   1.2s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=20, n_estimators=183; total time=   1.2s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=20, n_estimators=183; total time=   1.2s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=20, n_estimators=183; total time=   1.2s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=20, n_estimators=183; total time=   1.2s
# [CV] END max_depth=17, max_features=auto, min_samples_leaf=2, min_samples_split=22, n_estimators=200; total time=   7.4s
# [CV] END max_depth=17, max_features=auto, min_samples_leaf=2, min_samples_split=22, n_estimators=200; total time=   7.7s
# [CV] END max_depth=17, max_features=auto, min_samples_leaf=2, min_samples_split=22, n_estimators=200; total time=   7.7s
# [CV] END max_depth=17, max_features=auto, min_samples_leaf=2, min_samples_split=22, n_estimators=200; total time=  10.4s
# [CV] END max_depth=17, max_features=auto, min_samples_leaf=2, min_samples_split=22, n_estimators=200; total time=   9.0s
# [CV] END max_depth=12, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   7.2s
# [CV] END max_depth=12, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   7.0s
# [CV] END max_depth=12, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   6.7s
# [CV] END max_depth=12, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   6.5s
# [CV] END max_depth=12, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   6.2s
# [CV] END max_depth=17, max_features=auto, min_samples_leaf=7, min_samples_split=18, n_estimators=166; total time=   6.2s
# [CV] END max_depth=17, max_features=auto, min_samples_leaf=7, min_samples_split=18, n_estimators=166; total time=   5.9s
# [CV] END max_depth=17, max_features=auto, min_samples_leaf=7, min_samples_split=18, n_estimators=166; total time=   5.9s
# [CV] END max_depth=17, max_features=auto, min_samples_leaf=7, min_samples_split=18, n_estimators=166; total time=   6.1s
# [CV] END max_depth=17, max_features=auto, min_samples_leaf=7, min_samples_split=18, n_estimators=166; total time=   5.8s
# [CV] END max_depth=13, max_features=auto, min_samples_leaf=3, min_samples_split=15, n_estimators=100; total time=   3.1s
# [CV] END max_depth=13, max_features=auto, min_samples_leaf=3, min_samples_split=15, n_estimators=100; total time=   3.1s
# [CV] END max_depth=13, max_features=auto, min_samples_leaf=3, min_samples_split=15, n_estimators=100; total time=   3.1s
# [CV] END max_depth=13, max_features=auto, min_samples_leaf=3, min_samples_split=15, n_estimators=100; total time=   3.0s
# [CV] END max_depth=13, max_features=auto, min_samples_leaf=3, min_samples_split=15, n_estimators=100; total time=   3.0s
# [CV] END max_depth=14, max_features=sqrt, min_samples_leaf=4, min_samples_split=22, n_estimators=150; total time=   1.0s
# [CV] END max_depth=14, max_features=sqrt, min_samples_leaf=4, min_samples_split=22, n_estimators=150; total time=   0.9s
# [CV] END max_depth=14, max_features=sqrt, min_samples_leaf=4, min_samples_split=22, n_estimators=150; total time=   0.9s
# [CV] END max_depth=14, max_features=sqrt, min_samples_leaf=4, min_samples_split=22, n_estimators=150; total time=   0.9s
# [CV] END max_depth=14, max_features=sqrt, min_samples_leaf=4, min_samples_split=22, n_estimators=150; total time=   0.9s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=18, n_estimators=200; total time=   7.1s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=18, n_estimators=200; total time=   6.9s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=18, n_estimators=200; total time=   7.2s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=18, n_estimators=200; total time=   7.3s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=18, n_estimators=200; total time=   7.0s
# [CV] END max_depth=12, max_features=auto, min_samples_leaf=3, min_samples_split=20, n_estimators=133; total time=   4.0s
# [CV] END max_depth=12, max_features=auto, min_samples_leaf=3, min_samples_split=20, n_estimators=133; total time=   4.0s
# [CV] END max_depth=12, max_features=auto, min_samples_leaf=3, min_samples_split=20, n_estimators=133; total time=   4.1s
# [CV] END max_depth=12, max_features=auto, min_samples_leaf=3, min_samples_split=20, n_estimators=133; total time=   3.9s
# [CV] END max_depth=12, max_features=auto, min_samples_leaf=3, min_samples_split=20, n_estimators=133; total time=   3.8s
# [CV] END max_depth=12, max_features=sqrt, min_samples_leaf=7, min_samples_split=22, n_estimators=116; total time=   0.6s
# [CV] END max_depth=12, max_features=sqrt, min_samples_leaf=7, min_samples_split=22, n_estimators=116; total time=   0.5s
# [CV] END max_depth=12, max_features=sqrt, min_samples_leaf=7, min_samples_split=22, n_estimators=116; total time=   0.6s
# [CV] END max_depth=12, max_features=sqrt, min_samples_leaf=7, min_samples_split=22, n_estimators=116; total time=   0.6s
# [CV] END max_depth=12, max_features=sqrt, min_samples_leaf=7, min_samples_split=22, n_estimators=116; total time=   0.6s
# [CV] END max_depth=17, max_features=sqrt, min_samples_leaf=2, min_samples_split=15, n_estimators=66; total time=   0.4s
# [CV] END max_depth=17, max_features=sqrt, min_samples_leaf=2, min_samples_split=15, n_estimators=66; total time=   0.4s
# [CV] END max_depth=17, max_features=sqrt, min_samples_leaf=2, min_samples_split=15, n_estimators=66; total time=   0.4s
# [CV] END max_depth=17, max_features=sqrt, min_samples_leaf=2, min_samples_split=15, n_estimators=66; total time=   0.4s
# [CV] END max_depth=17, max_features=sqrt, min_samples_leaf=2, min_samples_split=15, n_estimators=66; total time=   0.4s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=24, n_estimators=83; total time=   2.4s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=24, n_estimators=83; total time=   2.2s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=24, n_estimators=83; total time=   2.1s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=24, n_estimators=83; total time=   2.1s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=24, n_estimators=83; total time=   2.2s
# [CV] END max_depth=12, max_features=sqrt, min_samples_leaf=4, min_samples_split=18, n_estimators=200; total time=   0.9s
# [CV] END max_depth=12, max_features=sqrt, min_samples_leaf=4, min_samples_split=18, n_estimators=200; total time=   1.0s
# [CV] END max_depth=12, max_features=sqrt, min_samples_leaf=4, min_samples_split=18, n_estimators=200; total time=   0.9s
# [CV] END max_depth=12, max_features=sqrt, min_samples_leaf=4, min_samples_split=18, n_estimators=200; total time=   1.0s
# [CV] END max_depth=12, max_features=sqrt, min_samples_leaf=4, min_samples_split=18, n_estimators=200; total time=   1.0s
# [CV] END max_depth=14, max_features=auto, min_samples_leaf=7, min_samples_split=10, n_estimators=50; total time=   1.1s
# [CV] END max_depth=14, max_features=auto, min_samples_leaf=7, min_samples_split=10, n_estimators=50; total time=   1.1s
# [CV] END max_depth=14, max_features=auto, min_samples_leaf=7, min_samples_split=10, n_estimators=50; total time=   1.1s
# [CV] END max_depth=14, max_features=auto, min_samples_leaf=7, min_samples_split=10, n_estimators=50; total time=   1.1s
# [CV] END max_depth=14, max_features=auto, min_samples_leaf=7, min_samples_split=10, n_estimators=50; total time=   1.1s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=83; total time=   0.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=83; total time=   0.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=83; total time=   0.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=83; total time=   0.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=83; total time=   0.4s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=22, n_estimators=66; total time=   1.4s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=22, n_estimators=66; total time=   1.3s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=22, n_estimators=66; total time=   1.2s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=22, n_estimators=66; total time=   1.2s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=22, n_estimators=66; total time=   1.2s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=7, min_samples_split=20, n_estimators=183; total time=   0.9s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=7, min_samples_split=20, n_estimators=183; total time=   0.9s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=7, min_samples_split=20, n_estimators=183; total time=   1.2s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=7, min_samples_split=20, n_estimators=183; total time=   1.3s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=7, min_samples_split=20, n_estimators=183; total time=   1.3s
# [CV] END max_depth=12, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=83; total time=   0.5s
# [CV] END max_depth=12, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=83; total time=   0.6s
# [CV] END max_depth=12, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=83; total time=   0.5s
# [CV] END max_depth=12, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=83; total time=   0.5s
# [CV] END max_depth=12, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=83; total time=   0.5s
# [CV] END max_depth=17, max_features=auto, min_samples_leaf=4, min_samples_split=20, n_estimators=83; total time=   2.9s
# [CV] END max_depth=17, max_features=auto, min_samples_leaf=4, min_samples_split=20, n_estimators=83; total time=   2.7s
# [CV] END max_depth=17, max_features=auto, min_samples_leaf=4, min_samples_split=20, n_estimators=83; total time=   2.7s
# [CV] END max_depth=17, max_features=auto, min_samples_leaf=4, min_samples_split=20, n_estimators=83; total time=   3.0s
# [CV] END max_depth=17, max_features=auto, min_samples_leaf=4, min_samples_split=20, n_estimators=83; total time=   3.6s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=7, min_samples_split=15, n_estimators=50; total time=   1.2s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=7, min_samples_split=15, n_estimators=50; total time=   1.1s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=7, min_samples_split=15, n_estimators=50; total time=   1.1s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=7, min_samples_split=15, n_estimators=50; total time=   1.1s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=7, min_samples_split=15, n_estimators=50; total time=   1.1s
# [CV] END max_depth=13, max_features=sqrt, min_samples_leaf=3, min_samples_split=15, n_estimators=183; total time=   1.2s
# [CV] END max_depth=13, max_features=sqrt, min_samples_leaf=3, min_samples_split=15, n_estimators=183; total time=   1.2s
# [CV] END max_depth=13, max_features=sqrt, min_samples_leaf=3, min_samples_split=15, n_estimators=183; total time=   1.2s
# [CV] END max_depth=13, max_features=sqrt, min_samples_leaf=3, min_samples_split=15, n_estimators=183; total time=   1.2s
# [CV] END max_depth=13, max_features=sqrt, min_samples_leaf=3, min_samples_split=15, n_estimators=183; total time=   1.2s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=7, min_samples_split=10, n_estimators=50; total time=   1.3s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=7, min_samples_split=10, n_estimators=50; total time=   1.4s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=7, min_samples_split=10, n_estimators=50; total time=   1.3s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=7, min_samples_split=10, n_estimators=50; total time=   1.3s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=7, min_samples_split=10, n_estimators=50; total time=   1.2s
# [CV] END max_depth=13, max_features=sqrt, min_samples_leaf=2, min_samples_split=20, n_estimators=183; total time=   1.1s
# [CV] END max_depth=13, max_features=sqrt, min_samples_leaf=2, min_samples_split=20, n_estimators=183; total time=   1.1s
# [CV] END max_depth=13, max_features=sqrt, min_samples_leaf=2, min_samples_split=20, n_estimators=183; total time=   1.0s
# [CV] END max_depth=13, max_features=sqrt, min_samples_leaf=2, min_samples_split=20, n_estimators=183; total time=   1.0s
# [CV] END max_depth=13, max_features=sqrt, min_samples_leaf=2, min_samples_split=20, n_estimators=183; total time=   0.9s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=24, n_estimators=116; total time=   0.4s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=24, n_estimators=116; total time=   0.4s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=24, n_estimators=116; total time=   0.4s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=24, n_estimators=116; total time=   0.5s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=24, n_estimators=116; total time=   0.5s
# RandomizedSearchCV(cv=5, estimator=GradientBoostingRegressor(), n_iter=30,
#                    n_jobs=1,
#                    param_distributions={'max_depth': [10, 12, 13, 14, 15, 17],
#                                         'max_features': ['auto', 'sqrt'],
#                                         'min_samples_leaf': [2, 3, 4, 5, 7, 10],
#                                         'min_samples_split': [10, 15, 18, 20,
#                                                               22, 24],
#                                         'n_estimators': [50, 66, 83, 100, 116,
#                                                          133, 150, 166, 183,
#                                                          200]},
#                    verbose=2)

# %%
gbr_tunned.best_params_
# Out:
# {'n_estimators': 183,
#  'min_samples_split': 15,
#  'min_samples_leaf': 3,
#  'max_features': 'sqrt',
#  'max_depth': 13}

# %%
y_pred = gbr_tunned.predict(X_test)
rmse = float(format(np.sqrt(mean_squared_error(y_test, y_pred)), '.3f'))
print("RMSE: ", rmse)
mse = float(format(mean_squared_error(y_test, y_pred), '.3f'))
print("MSE: ", mse)
r2 = float(format(r2_score(y_test, y_pred), '.3f'))
print("R2: ", r2)


models.append('Gradient Boost (t)')
rmse_lst.append(rmse)
mse_lst.append(mse)
r2_lst.append(r2)
# Out:
# RMSE:  1395.702
# MSE:  1947983.787
# R2:  0.903

# %%
gbr_tunned_importance = gbr_tunned.best_estimator_.feature_importances_
gbr_tunned_names = gbr_tunned.best_estimator_.feature_names_in_

gbr_tunned_import_df = pd.DataFrame({"feature_names" : gbr_tunned_names, 
                               "gbr_tunned_importances" : gbr_tunned_importance.round(3)})
gbr_tunned_import_df['gbr_tunned_impt_rank'] = gbr_tunned_import_df['gbr_tunned_importances'].rank(method='dense', ascending=False)

# %%
gbr_tunned_import_df.sort_values('gbr_tunned_importances', ascending=False).head(15)
# Out:
#                                   feature_names  gbr_tunned_importances  \
# 4                                  Duration_min                   0.279
# 5                                        Route2                   0.124
# 2                                       Dep_Day                   0.075
# 12                          Airline_Jet Airways                   0.064
# 3                                     Dep_Month                   0.057
# 0                                   Total_Stops                   0.051
# 13                 Airline_Jet Airways Business                   0.047
# 11                               Airline_IndiGo                   0.045
# 1                                        Dep_Hr                   0.037
# 36                      Additional_Info_No info                   0.027
# 6                                        Route3                   0.023
# 33  Additional_Info_In-flight meal not included                   0.023
# 25                            Destination_Delhi                   0.020
# 28                        Destination_New Delhi                   0.018
# 9                             Airline_Air India                   0.016
#
#     gbr_tunned_impt_rank
# 4                    1.0
# 5                    2.0
# 2                    3.0
# 12                   4.0
# 3                    5.0
# 0                    6.0
# 13                   7.0
# 11                   8.0
# 1                    9.0
# 36                  10.0
# 6                   11.0
# 33                  11.0
# 25                  12.0
# 28                  13.0
# 9                   14.0

# %%
sum_import_df_tunned = rf_tunned_import_df.merge(xgb_tunned_import_df,on='feature_names').merge(gbr_tunned_import_df,on='feature_names')
sum_import_df_tunned['overall_score'] = sum_import_df_tunned['rf_tunned_impt_rank'] + sum_import_df_tunned['xgb_tunned_impt_rank'] + sum_import_df_tunned['gbr_tunned_impt_rank']
sum_import_df_tunned['overall_rank'] = sum_import_df_tunned['overall_score'].rank(method='dense', ascending=True)

# %%
sum_import_df_tunned.sort_values('overall_rank', ascending=True)[['feature_names', 'rf_tunned_impt_rank', 'xgb_tunned_impt_rank', 'gbr_tunned_impt_rank', 'overall_score', 'overall_rank']]
# Out:
#                                    feature_names  rf_tunned_impt_rank  \
# 4                                   Duration_min                  1.0
# 12                           Airline_Jet Airways                  5.0
# 13                  Airline_Jet Airways Business                  4.0
# 33   Additional_Info_In-flight meal not included                  2.0
# 2                                        Dep_Day                  3.0
# 5                                         Route2                  7.0
# 0                                    Total_Stops                 12.0
# 3                                      Dep_Month                  6.0
# 11                                Airline_IndiGo                 13.0
# 28                         Destination_New Delhi                  8.0
# 36                       Additional_Info_No info                 14.0
# 6                                         Route3                 11.0
# 14                     Airline_Multiple carriers                 10.0
# 1                                         Dep_Hr                  9.0
# 9                              Airline_Air India                 13.0
# 16                              Airline_SpiceJet                 16.0
# 22                                Source_Kolkata                 14.0
# 23                                 Source_Mumbai                 15.0
# 26                         Destination_Hyderabad                 15.0
# 25                             Destination_Delhi                 17.0
# 21                                  Source_Delhi                 15.0
# 24                            Destination_Cochin                 15.0
# 41                              Weekday_Thursday                 17.0
# 10                                 Airline_GoAir                 17.0
# 43                             Weekday_Wednesday                 15.0
# 18                               Airline_Vistara                 15.0
# 40                                Weekday_Sunday                 15.0
# 38                                Weekday_Monday                 16.0
# 35  Additional_Info_No check-in baggage included                 18.0
# 42                               Weekday_Tuesday                 17.0
# 27                           Destination_Kolkata                 17.0
# 39                              Weekday_Saturday                 16.0
# 20                                Source_Chennai                 17.0
# 15     Airline_Multiple carriers Premium economy                 17.0
# 31                Additional_Info_Business class                 16.0
# 7                                         Route4                 18.0
# 30                Additional_Info_2 Long layover                 17.0
# 29               Additional_Info_1 Short layover                 17.0
# 32               Additional_Info_Change airports                 18.0
# 8                                         Route5                 18.0
# 34                       Additional_Info_No Info                 18.0
# 37                Additional_Info_Red-eye flight                 18.0
# 17                                Airline_Trujet                 18.0
# 19               Airline_Vistara Premium economy                 18.0
#
#     xgb_tunned_impt_rank  gbr_tunned_impt_rank  overall_score  overall_rank
# 4                    4.0                   1.0            6.0           1.0
# 12                   2.0                   4.0           11.0           2.0
# 13                   1.0                   7.0           12.0           3.0
# 33                   3.0                  11.0           16.0           4.0
# 2                   12.0                   3.0           18.0           5.0
# 5                   10.0                   2.0           19.0           6.0
# 0                    3.0                   6.0           21.0           7.0
# 3                   13.0                   5.0           24.0           8.0
# 11                   6.0                   8.0           27.0           9.0
# 28                   7.0                  13.0           28.0          10.0
# 36                   5.0                  10.0           29.0          11.0
# 6                    9.0                  11.0           31.0          12.0
# 14                   8.0                  17.0           35.0          13.0
# 1                   20.0                   9.0           38.0          14.0
# 9                   15.0                  14.0           42.0          15.0
# 16                  11.0                  17.0           44.0          16.0
# 22                  12.0                  18.0           44.0          16.0
# 23                  15.0                  15.0           45.0          17.0
# 26                  12.0                  19.0           46.0          18.0
# 25                  18.0                  12.0           47.0          19.0
# 21                  14.0                  19.0           48.0          20.0
# 24                  17.0                  17.0           49.0          21.0
# 41                  16.0                  18.0           51.0          22.0
# 10                  14.0                  20.0           51.0          22.0
# 43                  20.0                  17.0           52.0          23.0
# 18                  17.0                  20.0           52.0          23.0
# 40                  21.0                  16.0           52.0          23.0
# 38                  19.0                  18.0           53.0          24.0
# 35                  17.0                  22.0           57.0          25.0
# 42                  21.0                  20.0           58.0          26.0
# 27                  23.0                  19.0           59.0          27.0
# 39                  22.0                  21.0           59.0          27.0
# 20                  21.0                  22.0           60.0          28.0
# 15                  20.0                  23.0           60.0          28.0
# 31                  24.0                  23.0           63.0          29.0
# 7                   23.0                  22.0           63.0          29.0
# 30                  24.0                  23.0           64.0          30.0
# 29                  24.0                  23.0           64.0          30.0
# 32                  23.0                  23.0           64.0          30.0
# 8                   24.0                  23.0           65.0          31.0
# 34                  24.0                  23.0           65.0          31.0
# 37                  24.0                  23.0           65.0          31.0
# 17                  24.0                  23.0           65.0          31.0
# 19                  24.0                  23.0           65.0          31.0

# %%
data = {'models': models,
        'rmse': rmse_lst,
        'mse': mse_lst,
        'r2': r2_lst
        }

df_result_sum2 = pd.DataFrame(data)

# %%
df_result_sum2
# Out:
#                models      rmse           mse     r2
# 0                Dumb  4482.259  2.009064e+07 -0.001
# 1   Linear Regression  2548.299  6.493826e+06  0.703
# 2    Ridge Regression  2550.610  6.505614e+06  0.702
# 3       Random Forest  1447.606  2.095563e+06  0.896
# 4             XGBoost  1365.164  1.863674e+06  0.907
# 5      Gradient Boost  1707.201  2.914535e+06  0.855
# 6   Random Forest (t)  1426.809  2.035784e+06  0.899
# 7         XGBoost (t)  1348.061  1.817269e+06  0.909
# 8  Gradient Boost (t)  1395.702  1.947984e+06  0.903

# %%
#Conclusion

#The best model is XG Boost with a r2 of 0.9.
#Some of the best feature are Duration_min, Additional_Info, Airline_Jet, Depature (Hour/Day), Route.
#It is quite suprirsing that Departure (hour & day) features are ranked in the top few as our initial EDA did not suggest clear difference towards prices. (Perhaps the label coding may have caused for some overfitting).
#Another observation is that the bottom performing features are mainly because they are mostly null values.
#There isn't much improved in score after using tunned models. RandomizeSearch was used, perhaps not a comprehensive tunning which results in missing better parameters.
#Random Forest and Gradient Boosting give very similar ranking of features unlike XGBoost after the 4th ranked feature.
